# %%
# coding:utf-8
'''燃油及工信部整合数据，匹配车型库，完成车型ID与整车型号的映射

程序匹配前数据整理：
1.燃油&工信部数据.csv：
    [自定义ID,车系，排量，驱动形式，变速，功率，燃料，整备质量，发动机型号，长宽高]
2.车型库数据.csv:
    [车型库ID,车系，排量，驱动形式，变速，功率，燃料，整备质量，发动机型号，长，宽，高]
'''
import csv
import codecs

class FileCSV(object):
    def __init__(self):
        pass
    
    def read_file(self,file_name):
        '''读取csv文件，结果为以每行数据为列表（元素为每列属性）的总列表'''
        try:
            with open(file_name,'r') as file:
                contents = file.readlines()
        except FileNotFoundError:
            print('文件%s不存在' % file_name)
            return None
        else:
            results = [] 
            for line in contents:
                results.append(line.strip().split(','))
        return results
    
    def write_file(self,file_name,lists):
        with open(file_name,'w',newline='',encoding='utf-8') as f:
            write = csv.writer(f)
            write.writerows(lists)
    
    def utf8_2_gbk(self,file_name):
        '''将utf8格式的csv文件转为gbk格式'''
        newfile = "gbk_%s" % file_name
        try:
            with codecs.open(file_name, 'r', 'utf-8') as f:
                utf_str = f.read()
                out_gbk_str = utf_str.encode('GB18030')
        except FileNotFoundError:
            print('文件%s不存在' % file_name)
            return None
        else:
            with open(newfile,'wb') as ff:
                ff.write(out_gbk_str)
    
    def onebyone_2_onebymore(self,file_name):
        '''将一一对应的两列数据，转为一对多形式'''
        read_results = self.read_file(file_name)
        transformation_results = {}
        for i in read_results:
            if i[0] in transformation_results:
                transformation_results[i[0]].append(i[1])
            else:
                transformation_results[i[0]] = [i[1]]
        with open('onebymore_%s' % file_name,'w',newline='',encoding='utf-8') as f:
            write = csv.writer(f)
            for k,v in transformation_results.items():
                v = str(v).replace('[','').replace(']','').replace("'","").replace(' ','')
                write.writerow([k,str(v)])
        
        
class Match(object):
    def __init__(self,fuel_list,vehicle_list):
        # 燃油&工信部字段
        self.fuel_list = fuel_list
        self.fuel_id = fuel_list[0]
        self.fuel_series = fuel_list[1]
        self.fuel_displacement = fuel_list[2]
        self.fuel_drive = fuel_list[3]
        self.fuel_trans = fuel_list[4]
        self.fuel_power = fuel_list[5]
        self.fuel_type = fuel_list[6]
        self.fuel_weight = fuel_list[7]
        self.fuel_engine_code = fuel_list[8]
        
        self.fuel_long_width_height = fuel_list[9]
        
        # 车型库字段
        self.vehicle_list = vehicle_list
        self.vehicle_id = vehicle_list[0]
        self.vehicle_series = vehicle_list[1]
        self.vehicle_displacement = vehicle_list[2]
        self.vehicle_drive = vehicle_list[3]
        self.vehicle_trans = vehicle_list[4]
        self.vehicle_power = vehicle_list[5]
        self.vehicle_type = vehicle_list[6]
        self.vehicle_weight = vehicle_list[7]
        self.vehicle_engine_code = vehicle_list[8]
        
        self.vehicle_long = vehicle_list[9]
        self.vehicle_width = vehicle_list[10]
        self.vehicle_height = vehicle_list[11]
    
    # 整合工信部数据匹配类型：
    def exact_match(self):
        '''精确匹配 - 催毛求疵'''
        # 1.条件字段处理
        self.fuel_condition = ''
        self.vehicle_condition = ''
        for i in range(1,9):
            self.fuel_condition += self.fuel_list[i]
            self.vehicle_condition += self.vehicle_list[i]
        # 2.长宽高处理
        if self.fuel_condition == self.vehicle_condition:
            for j in [self.vehicle_long,self.vehicle_width,self.vehicle_height]:
                if j not in self.fuel_long_width_height:
                    return False
            return [self.fuel_id,self.vehicle_id,'精确匹配']
        else:
            return False
    
    def standard_match(self):
        '''标准匹配 - 忽略车系，整备质量，发动机型号'''
        # 1.条件字段处理
        self.fuel_condition = ''
        self.vehicle_condition = ''
        for i in range(2,7):
            self.fuel_condition += self.fuel_list[i]
            self.vehicle_condition += self.vehicle_list[i]
        # 2.长宽高处理
        if self.fuel_condition == self.vehicle_condition:
            for j in [self.vehicle_long,self.vehicle_width,self.vehicle_height]:
                if j not in self.fuel_long_width_height:
                    return False
            return [self.fuel_id,self.vehicle_id,'标准匹配']

    def fuzzy_match_1():
        '''模糊匹配 - ？'''
        pass
    
    # 未整合工信部数据匹配类型：
    def no_gov_exact_match(self):
        '''无工信部数据的精确匹配，即忽略长宽高限定条件'''
        # 1.条件字段处理
        self.fuel_condition = ''
        self.vehicle_condition = ''
        for i in range(1,9):
            self.fuel_condition += self.fuel_list[i]
            self.vehicle_condition += self.vehicle_list[i]
        if self.fuel_condition == self.vehicle_condition:
            return [self.fuel_id,self.vehicle_id,'无工信部-精确匹配']
        else:
            return False
        
    def no_gov_standard_match(self):
        '''无工信部数据的标准匹配 - 忽略整备质量，发动机型号'''
        # 1.条件字段处理
        self.fuel_condition = self.fuel_series
        self.vehicle_condition = self.vehicle_series
        for i in range(2,7):
            self.fuel_condition += self.fuel_list[i]
            self.vehicle_condition += self.vehicle_list[i]
        if self.fuel_condition == self.vehicle_condition:
            return [self.fuel_id,self.vehicle_id,'无工信部-标准匹配']

# %%
'''
工信部&燃油整合数据处理
'''
# 第一步，读取文件
# 实例化文件类
file = FileCSV()
fuel = file.read_file('fuel.csv')
vehicle = file.read_file('vehicle.csv')

# 结果初始化
results = []

# 第二步，遍历燃油&工信部数据总列表,实现各种匹配
count_print = 0
for fuel_single in fuel:
    count_print += 1
    print('第%s条记录正在匹配' % count_print)
    # 遍历车型库，匹配
    for vehicle_single in vehicle:
        # 实例化匹配类
        match = Match(fuel_single,vehicle_single)
        exact_result = match.exact_match()
        standard_result = match.standard_match()
        
        # 第三步，各种匹配结果存储
        if exact_result:
            results.append(exact_result)
        if standard_result:
            results.append(standard_result)
    
# 第四步，所有匹配结果写入csv，并转码
file.write_file('result.csv',results)
file.utf8_2_gbk('result.csv')
    
print('GameOver!')

# %%
'''
无工信部的燃油数据处理
'''
# 第一步，读取文件
# 实例化文件类
file = FileCSV()
no_gov_fuel = file.read_file('no_gov_fuel.csv')
no_gov_vehicle = file.read_file('no_gov_vehicle.csv')

# 结果初始化
no_gov_results = []

# 第二步，遍历无工信部的燃油数据总列表,实现各种匹配
count_print = 0
for fuel_single in no_gov_fuel:
    count_print += 1
    print('第%s条记录正在匹配' % count_print)
    # 遍历车型库，匹配
    for vehicle_single in no_gov_vehicle:
        # 实例化匹配类
        match = Match(fuel_single,vehicle_single)
        no_gov_exact_result = match.no_gov_exact_match()
        no_gov_standard_result = match.no_gov_standard_match()
        
        # 第三步，各种匹配结果存储
        if no_gov_exact_result:
            no_gov_results.append(no_gov_exact_result)
        if no_gov_standard_result:
            no_gov_results.append(no_gov_standard_result)
    
# 第四步，所有匹配结果写入csv，并转码
file.write_file('no_gov_result.csv',no_gov_results)
file.utf8_2_gbk('no_gov_result.csv')
    
print('GameOver!')

# %%
# 结果处理后，由一对一数据转为一对多数据

file = FileCSV()
transformation1 = file.onebyone_2_onebymore('no_gov_one_one.csv')

# %%
'''
历史结果与更新结果整合（更新结果和历史结果可能出现同整车型号交叉等）
将整理的[车型ID,历史总结果，更新总结果]形式csv文件
处理为[车型ID,结果整合]形式csv文件
'''
import csv

file_name = 'history_new_result.csv'
try:
    with open(file_name,'r') as file:
        contents = file.readlines()
except FileNotFoundError:
    print('文件%s不存在' % file_name)
else:
    for line in contents:
        line_list = line.strip().split(',')
        vehicle_id = line_list[0]
        result_history = line_list[1]
        result_new = line_list[2]

        if result_history:
            result_history_list = result_history.split(';')
        else:
            result_history_list = []
        if result_new:
            result_new_list = result_new.split(';')
        else:
            result_new_list = []
            
        finally_result = list(set(result_history_list + result_new_list))
        finally_result.sort()
        
        print(vehicle_id,finally_result)
        
        # 列表相加去重
# Out:
# ['2739', '', 'FV7162SAT']
# [] ['FV7162SAT']
# ['2724', '', 'FV7162SAT']
# [] ['FV7162SAT']
# ['1519', '', 'FV7162AT E4']
# [] ['FV7162AT E4']
# ['1520', '', '']
# [] []
# ['2418', '', 'FV7162FAT']
# [] ['FV7162FAT']
# ['2420', '', 'FV7162FAT']
# [] ['FV7162FAT']
# ['2738', '', 'FV7162S']
# [] ['FV7162S']
# ['2740', '', 'FV7162S']
# [] ['FV7162S']
# ['1517', '', 'FV7162 E4']
# [] ['FV7162 E4']
# ['1518', '', '']
# [] []
# ['2416', '', 'FV7162F']
# [] ['FV7162F']
# ['2419', '', 'FV7162F']
# [] ['FV7162F']
# ['456', '', '']
# [] []
# ['466', '', '']
# [] []
# ['454', '', '']
# [] []
# ['763', '', '']
# [] []
# ['2742', '', 'FV7182SAT']
# [] ['FV7182SAT']
# ['524', '', '']
# [] []
# ['764', '', '']
# [] []
# ['518', '', '']
# [] []
# ['1792', '', 'BORA 1.8 AT']
# [] ['BORA 1.8 AT']
# ['1793', '', '']
# [] []
# ['2421', '', 'FV7182FAT']
# [] ['FV7182FAT']
# ['2741', '', 'FV7182S']
# [] ['FV7182S']
# ['534', '', '']
# [] []
# ['519', '', '']
# [] []
# ['516', '', '']
# [] []
# ['1548', '', 'BORA 1.8T']
# [] ['BORA 1.8T']
# ['1806', '', '']
# [] []
# ['2417', '', 'FV7182F']
# [] ['FV7182F']
# ['538', '', '']
# [] []
# ['762', '', 'BORA 1.8T AT']
# [] ['BORA 1.8T AT']
# ['539', '', '']
# [] []
# ['716', '', '']
# [] []
# ['714', '', '']
# [] []
# ['1739', '', 'FV7182TR']
# [] ['FV7182TR']
# ['1396', '', 'BORA 1.9TDi']
# [] ['BORA 1.9TDi']
# ['19648', '', '']
# [] []
# ['14885', '', 'FV7140BAMGG']
# [] ['FV7140BAMGG']
# ['14886', '', 'FV7140BAMGG']
# [] ['FV7140BAMGG']
# ['23208', '', 'FV7140BAMBG']
# [] ['FV7140BAMBG']
# ['20258', '', 'FV7140BAMAG;FV7140BAMBG']
# [] ['FV7140BAMAG', 'FV7140BAMBG']
# ['23209', '', 'FV7140BAMBG']
# [] ['FV7140BAMBG']
# ['20259', '', 'FV7140BAMAG;FV7140BAMBG']
# [] ['FV7140BAMAG', 'FV7140BAMBG']
# ['28706', '', 'FV7140FAMBG']
# [] ['FV7140FAMBG']
# ['28707', '', 'FV7140FAMBG']
# [] ['FV7140FAMBG']
# ['37063', '', 'FV7140FAMBG']
# [] ['FV7140FAMBG']
# ['37064', '', 'FV7140FAMBG']
# [] ['FV7140FAMBG']
# ['23201', '', 'FV7140BCDBG']
# [] ['FV7140BCDBG']
# ['20102', '', 'FV7140BCDBG']
# [] ['FV7140BCDBG']
# ['28712', '', 'FV7140FDDBG']
# [] ['FV7140FDDBG']
# ['28711', '', 'FV7150FCMBG']
# [] ['FV7150FCMBG']
# ['28708', '', 'FV7150FCMBG']
# [] ['FV7150FCMBG']
# ['28710', '', 'FV7150FCMBG']
# [] ['FV7150FCMBG']
# ['37065', '', 'FV7150FCMBG']
# [] ['FV7150FCMBG']
# ['37067', '', 'FV7150FCMBG']
# [] ['FV7150FCMBG']
# ['28451', '', 'FV7150FCBBG']
# [] ['FV7150FCBBG']
# ['28353', '', 'FV7150FCBBG']
# [] ['FV7150FCBBG']
# ['28709', '', 'FV7150FCBBG']
# [] ['FV7150FCBBG']
# ['37068', '', 'FV7150FCBBG']
# [] ['FV7150FCBBG']
# ['37066', '', 'FV7150FCBBG']
# [] ['FV7150FCBBG']
# ['14890', '', 'FV7160BBMGG']
# [] ['FV7160BBMGG']
# ['14887', '', 'FV7160BBMGG']
# [] ['FV7160BBMGG']
# ['14888', '', 'FV7160BBMGG']
# [] ['FV7160BBMGG']
# ['20264', '', 'FV7160BBMAG;FV7160BBMBG']
# [] ['FV7160BBMAG', 'FV7160BBMBG']
# ['23197', '', 'FV7160BBMBG']
# [] ['FV7160BBMBG']
# ['20260', '', 'FV7160BBMAG;FV7160BBMBG']
# [] ['FV7160BBMAG', 'FV7160BBMBG']
# ['23199', '', 'FV7160BBMBG']
# [] ['FV7160BBMBG']
# ['20262', '', 'FV7160BBMAG;FV7160BBMBG']
# [] ['FV7160BBMAG', 'FV7160BBMBG']
# ['14889', '', 'FV7160BBAGG']
# [] ['FV7160BBAGG']
# ['14540', '', 'FV7160BBAGG']
# [] ['FV7160BBAGG']
# ['18644', '', 'FV7160BBBBG;FV7160BBBAG;FV7160BBAGG;FV7160BBAWG;FV7160BBBGG;FV7160BBBWG']
# [] ['FV7160BBBBG', 'FV7160BBBAG', 'FV7160BBAGG', 'FV7160BBAWG', 'FV7160BBBGG', 'FV7160BBBWG']
# ['23200', '', 'FV7160BBBBG']
# [] ['FV7160BBBBG']
# ['20263', '', 'FV7160BBBWG;FV7160BBBGG']
# [] ['FV7160BBBWG', 'FV7160BBBGG']
# ['20266', '', 'FV7160BBBWG;FV7160BBBGG']
# [] ['FV7160BBBWG', 'FV7160BBBGG']
# ['23198', '', 'FV7160BBBBG']
# [] ['FV7160BBBBG']
# ['20261', '', 'FV7160BBBWG;FV7160BBBGG']
# [] ['FV7160BBBWG', 'FV7160BBBGG']
# ['26294', '', 'FV7160BBBBG']
# [] ['FV7160BBBBG']
# ['1465', '', 'FV7160CiF E3']
# [] ['FV7160CiF E3']
# ['4182', '', '']
# [] []
# ['1846', '', 'FV7160GiFE;FV7160CiF L;FV7160CiFE;FV7160CiF C']
# [] ['FV7160GiFE', 'FV7160CiF L', 'FV7160CiFE', 'FV7160CiF C']
# ['793', '', 'FV7160GiF E3']
# [] ['FV7160GiF E3']
# ['6827', '', 'FV7160CiF E3']
# [] ['FV7160CiF E3']
# ['792', '', 'FV7160CiF E3']
# [] ['FV7160CiF E3']
# ['2484', '', 'FV7160GiFE;FV7160CiF L;FV7160CiFE;FV7160CiF C']
# [] ['FV7160GiFE', 'FV7160CiF L', 'FV7160CiFE', 'FV7160CiF C']
# ['1170', '', 'FV7160GiFE;FV7160CiF L;FV7160CiFE;FV7160CiF C']
# [] ['FV7160GiFE', 'FV7160CiF L', 'FV7160CiFE', 'FV7160CiF C']
# ['4181', '', 'FV7160GiFE']
# [] ['FV7160GiFE']
# ['6816', '', 'FV7160CiXG']
# [] ['FV7160CiXG']
# ['4179', '', '']
# [] []
# ['4765', '', '']
# [] []
# ['7286', '', 'FV7160FG']
# [] ['FV7160FG']
# ['7288', '', 'FV7160FG']
# [] ['FV7160FG']
# ['12575', '', 'FV7160FG']
# [] ['FV7160FG']
# ['13490', '', 'FV7160FG']
# [] ['FV7160FG']
# ['9707', '', 'FV7160FG;FV7160FE']
# [] ['FV7160FG', 'FV7160FE']
# ['4762', '', 'FV7160CiFG']
# [] ['FV7160CiFG']
# ['4764', '', 'FV7160CiFE;FV7160CiF C;FV7160CiFG;FV7160GiFE;FV7160CiF L']
# [] ['FV7160CiFE', 'FV7160CiF C', 'FV7160CiFG', 'FV7160GiFE', 'FV7160CiF L']
# ['7287', '', 'FV7190FSDI']
# [] ['FV7190FSDI']
# ['1466', '', 'FV7190GDF']
# [] ['FV7190GDF']
# ['4763', '', 'FV7190GDF']
# [] ['FV7190GDF']
# ['4180', '', 'FV7190GDF']
# [] ['FV7190GDF']
# ['11434', '', '']
# [] []
# ['5897', '', '']
# [] []
# ['7271', '', '']
# [] []
# ['9399', '', '']
# [] []
# ['14971', '', '']
# [] []
# ['19004', '', '']
# [] []
# ['22611', '', '']
# [] []
# ['19032', '', '']
# [] []
# ['18879', '', '']
# [] []
# ['20452', '', '']
# [] []
# ['26894', '', '']
# [] []
# ['30714', '', '']
# [] []
# ['33649', '', '']
# [] []
# ['33997', '', '']
# [] []
# ['40997', '', '']
# [] []
# ['38065', '', '']
# [] []
# ['35819', '', '']
# [] []
# ['5607', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['5608', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['5609', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['8943', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['8944', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['8945', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['7272', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['22947', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['22948', '', 'TOUAREG 3.0 TDI']
# [] ['TOUAREG 3.0 TDI']
# ['8936', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['8937', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['8914', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['8938', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['14024', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['14531', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['17966', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['18038', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['22949', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['22950', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['22951', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['22952', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['15287', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['9476', '', 'TOUAREG 3.0']
# [] ['TOUAREG 3.0']
# ['22954', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['21501', '', 'TOUAREG 3.0;TOUAREG CJTAAA8501']
# [] ['TOUAREG 3.0', 'TOUAREG CJTAAA8501']
# ['23930', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['23931', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['26765', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['31175', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['26766', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['30736', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['34600', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['23932', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['23933', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['26767', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['26768', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['27353', '', 'TOUAREG CYJAAA8501']
# [] ['TOUAREG CYJAAA8501']
# ['7121', '', '']
# [] []
# ['40998', '', '']
# [] []
# ['35820', '', 'TOUAREG DCBEQA8501']
# [] ['TOUAREG DCBEQA8501']
# ['40999', '', '']
# [] []
# ['35821', '', 'TOUAREG DCBEQA8501']
# [] ['TOUAREG DCBEQA8501']
# ['411', '', '']
# [] []
# ['6836', '', '']
# [] []
# ['2208', '', '']
# [] []
# ['2720', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['2721', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['2722', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['2723', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['7003', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['7004', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['6593', '', 'TOUAREG 3.6;TOUAREG 3.6 C5']
# [] ['TOUAREG 3.6', 'TOUAREG 3.6 C5']
# ['15097', '', 'TOUAREG 3.6']
# [] ['TOUAREG 3.6']
# ['15098', '', 'TOUAREG 3.6']
# [] ['TOUAREG 3.6']
# ['419', '', '']
# [] []
# ['2833', '', '']
# [] []
# ['2832', '', '']
# [] []
# ['7005', '', '']
# [] []
# ['17495', '', 'TOUAREG 4.2 C5']
# [] ['TOUAREG 4.2 C5']
# ['3739', '', 'TOUAREG 6.0']
# [] ['TOUAREG 6.0']
# ['21686', '', '']
# [] []
# ['26355', '', 'SHARAN CZDAFD6501']
# [] ['SHARAN CZDAFD6501']
# ['31424', '', 'SHARAN CZDAFD6501']
# [] ['SHARAN CZDAFD6501']
# ['958', '', '']
# [] []
# ['16209', '', '']
# [] []
# ['14812', '', '']
# [] []
# ['16210', '', '']
# [] []
# ['14813', '', 'SHARAN 1.8 TSI']
# [] ['SHARAN 1.8 TSI']
# ['26133', '', '']
# [] []
# ['11881', '', '']
# [] []
# ['7180', '', '']
# [] []
# ['11882', '', '']
# [] []
# ['16206', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['16207', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['16208', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['20502', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['20503', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['20504', '', 'SHARAN 2.0 TSI']
# [] ['SHARAN 2.0 TSI']
# ['26666', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['26364', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['26365', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['26667', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['29848', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['29849', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['29847', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['29850', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['35690', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['35726', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31425', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31426', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['35691', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['35727', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31427', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31428', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31429', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['31430', '', 'SHARAN DEDAFD6501']
# [] ['SHARAN DEDAFD6501']
# ['41106', '', '']
# [] []
# ['41107', '', '']
# [] []
# ['499', '', '']
# [] []
# ['1070', '', 'SVW7165BNi']
# [] ['SVW7165BNi']
# ['597', '', 'SVW7165ANi']
# [] ['SVW7165ANi']
# ['924', '', 'SVW7165ANi']
# [] ['SVW7165ANi']
# ['676', '', 'SVW7165ANi']
# [] ['SVW7165ANi']
# ['574', '', 'SVW7165BNi']
# [] ['SVW7165BNi']
# ['1860', '', 'SVW7165BNi']
# [] ['SVW7165BNi']
# ['1177', '', 'SVW7165BNi']
# [] ['SVW7165BNi']
# ['39247', '', '']
# [] []
# ['39256', '', '']
# [] []
# ['749', '', 'SVW7144CLi']
# [] ['SVW7144CLi']
# ['744', '', 'SVW7144CLi']
# [] ['SVW7144CLi']
# ['755', '', 'SVW7144HLi;SVW7144NLi']
# [] ['SVW7144HLi', 'SVW7144NLi']
# ['869', '', 'SVW7144ALi']
# [] ['SVW7144ALi']
# ['750', '', 'SVW7144ALi;SVW7144BLi']
# [] ['SVW7144ALi', 'SVW7144BLi']
# ['747', '', 'SVW7144ALi;SVW7144BLi']
# [] ['SVW7144ALi', 'SVW7144BLi']
# ['756', '', 'SVW7144GLi;SVW7144MLi']
# [] ['SVW7144GLi', 'SVW7144MLi']
# ['754', '', 'SVW7144GLi;SVW7144MLi']
# [] ['SVW7144GLi', 'SVW7144MLi']
# ['753', '', 'SVW7144GLi;SVW7144MLi']
# [] ['SVW7144GLi', 'SVW7144MLi']
# ['2337', '', 'SVW7144PRi']
# [] ['SVW7144PRi']
# ['2400', '', 'SVW7144PRi']
# [] ['SVW7144PRi']
# ['3527', '', 'SVW7144ARI']
# [] ['SVW7144ARI']
# ['3524', '', 'SVW7144ARD']
# [] ['SVW7144ARD']
# ['5806', '', 'SVW7144PRD;SVW7144ARi;SVW7144ARD']
# [] ['SVW7144PRD', 'SVW7144ARi', 'SVW7144ARD']
# ['5807', '', 'SVW7144ARD']
# [] ['SVW7144ARD']
# ['9120', '', 'SVW71411AR']
# [] ['SVW71411AR']
# ['9121', '', 'SVW71411AR']
# [] ['SVW71411AR']
# ['14489', '', 'SVW71411NR']
# [] ['SVW71411NR']
# ['14490', '', 'SVW71411NR']
# [] ['SVW71411NR']
# ['10297', '', 'SVW7144GRD;SVW7144LRD']
# [] ['SVW7144GRD', 'SVW7144LRD']
# ['10296', '', 'SVW7144GRD;SVW7144LRD']
# [] ['SVW7144GRD', 'SVW7144LRD']
# ['2396', '', 'SVW7144RRi']
# [] ['SVW7144RRi']
# ['2399', '', 'SVW7144RRi']
# [] ['SVW7144RRi']
# ['3523', '', 'SVW7144CRD']
# [] ['SVW7144CRD']
# ['3522', '', 'SVW7144CRD']
# [] ['SVW7144CRD']
# ['5811', '', 'SVW7144CRD']
# [] ['SVW7144CRD']
# ['5812', '', 'SVW7144CRD']
# [] ['SVW7144CRD']
# ['2401', '', 'SVW7144QRD']
# [] ['SVW7144QRD']
# ['2393', '', 'SVW7144QRD']
# [] ['SVW7144QRD']
# ['3525', '', 'SVW7144BRD']
# [] ['SVW7144BRD']
# ['3526', '', 'SVW7144BRi']
# [] ['SVW7144BRi']
# ['5808', '', 'SVW7144BRD']
# [] ['SVW7144BRD']
# ['9122', '', 'SVW71411BR']
# [] ['SVW71411BR']
# ['9124', '', 'SVW71411BR']
# [] ['SVW71411BR']
# ['14491', '', 'SVW71411PR']
# [] ['SVW71411PR']
# ['14494', '', 'SVW71411PR']
# [] ['SVW71411PR']
# ['10295', '', 'SVW7144HRD']
# [] ['SVW7144HRD']
# ['2397', '', 'SVW7144SRi']
# [] ['SVW7144SRi']
# ['3521', '', 'SVW7144DRi']
# [] ['SVW7144DRi']
# ['5813', '', 'SVW7144DRD']
# [] ['SVW7144DRD']
# ['19250', '', 'SVW71411GR']
# [] ['SVW7164BSi']
# ['5364', '', 'SVW7164BSD']
# [] ['SVW7164BSD']
# ['5810', '', 'SVW7164USD;SVW7164USi;SVW7164BSi;SVW7164BSD']
# [] ['SVW7164USD', 'SVW7164USi', 'SVW7164BSi', 'SVW7164BSD']
# ['3548', '', 'SVW7164FSi;SVW7164FSD']
# [] ['SVW7164FSi', 'SVW7164FSD']
# ['9125', '', 'SVW71611DS']
# [] ['SVW71611DS']
# ['7274', '', 'SVW71611DS']
# [] ['SVW71611DS']
# ['14493', '', 'SVW71611RS']
# [] ['SVW71611RS']
# ['14495', '', 'SVW71611KS']
# [] ['SVW71611KS']
# ['11376', '', 'SVW71611HS']
# [] ['SVW71611HS']
# ['10293', '', 'SVW7164KSD']
# [] ['SVW7164KSD']
# ['2385', '', 'SVW7164WSi']
# [] ['SVW7164WSi']
# ['3518', '', 'SVW7164DSi']
# [] ['SVW7164DSi']
# ['5815', '', 'SVW7164DSD']
# [] ['SVW7164DSD']
# ['19254', '', 'SVW71611AM']
# [] ['SVW71611AM']
# ['25381', '', 'SVW71611AM;SVW71611NM']
# [] ['SVW71611AM', 'SVW71611NM']
# ['19206', '', 'SVW71611CM']
# [] ['SVW71611CM']
# ['19255', '', 'SVW71611BM']
# [] ['SVW71611BM']
# ['19180', '', 'SVW71611BM']
# [] ['SVW71611BM']
# ['19893', '', 'SVW71611BM;SVW71611LM']
# [] ['SVW71611BM', 'SVW71611LM']
# ['19249', '', 'SVW71611DM']
# [] ['SVW71611DM']
# ['25389', '', 'SVW71611DM;SVW71611MM']
# [] ['SVW71611DM', 'SVW71611MM']
# ['25382', '', 'SVW71611BM;SVW71611LM']
# [] ['SVW71611BM', 'SVW71611LM']
# ['25384', '', 'SVW71611BM']
# [] ['SVW71611BM']
# ['631', '', 'SVW7160FHi']
# [] ['SVW7160FHi']
# ['839', '', 'SVW7160FHi']
# [] ['SVW7160FHi']
# ['650', '', 'SVW7180LED;SVW7180CEi;SVW7180LEi']
# [] ['SVW7180LED', 'SVW7180CEi', 'SVW7180LEi']
# ['636', '', 'SVW7180LED;SVW7180CEi;SVW7180LEi']
# [] ['SVW7180LED', 'SVW7180CEi', 'SVW7180LEi']
# ['198', '', 'SVW7180CEi;SVW7181CEi']
# [] ['SVW7180CEi', 'SVW7181CEi']
# ['6814', '', 'SVW7181LEi']
# [] ['SVW7181LEi']
# ['1176', '', 'SVW7180LED']
# [] ['SVW7180LED']
# ['8249', '', 'SVW7162AMD']
# [] ['SVW7162AMD']
# ['8250', '', 'SVW7162AMD']
# [] ['SVW7162AMD']
# ['580', '', 'SVW7182LFi;SVW7182DQi']
# [] ['SVW7182LFi', 'SVW7182DQi']
# ['171', '', 'SVW7182LFi;SVW7182DQi']
# [] ['SVW7182LFi', 'SVW7182DQi']
# ['2347', '', 'SVW7182LFi;SVW7182DQi']
# [] ['SVW7182LFi', 'SVW7182DQi']
# ['169', '', 'SVW7182KFi']
# [] ['SVW7182KFi']
# ['1068', '', 'SVW7182KFi']
# ['34184', '', 'BEETLE CYVDFD7501']
# [] ['BEETLE CYVDFD7501']
# ['31898', '', 'BEETLE CYVDFD7501']
# [] ['BEETLE CYVDFD7501']
# ['37055', '', 'BEETLE CYVDFD7501']
# [] ['BEETLE CYVDFD7501']
# ['26489', '', 'BEETLE D CYVDFD7501']
# [] ['BEETLE D CYVDFD7501']
# ['26649', '', 'BEETLE CYVDFD7501']
# [] ['BEETLE CYVDFD7501']
# ['28603', '', 'BEETLE D CYVDFD7501']
# [] ['BEETLE D CYVDFD7501']
# ['31574', '', 'BEETLE CYVDFD7501']
# [] ['BEETLE CYVDFD7501']
# ['28583', '', 'BEETLE CZDAFD7501']
# [] ['BEETLE CZDAFD7501']
# ['28584', '', 'BEETLE CZDAFD7501']
# [] ['BEETLE CZDAFD7501']
# ['31575', '', 'BEETLE CZDAFD7501']
# [] ['BEETLE CZDAFD7501']
# ['31576', '', 'BEETLE CZDAFD7501']
# [] ['BEETLE CZDAFD7501']
# ['26490', '', '']
# [] []
# ['28604', '', 'BEETLE D CZDAFD7501']
# [] ['BEETLE D CZDAFD7501']
# ['31577', '', 'BEETLE CZDAFD7501']
# [] ['BEETLE CZDAFD7501']
# ['13774', '', 'BEETLE 1.4']
# [] ['BEETLE 1.4']
# ['13519', '', 'BEETLE 1.4']
# [] ['BEETLE 1.4']
# ['13003', '', 'BEETLE 1.4']
# [] ['BEETLE 1.4']
# ['13528', '', 'BEETLE 1.4']
# [] ['BEETLE 1.4']
# ['13859', '', '']
# [] []
# ['17112', '', '']
# [] []
# ['17113', '', '']
# [] []
# ['17114', '', '']
# [] []
# ['17115', '', 'BEETLE 1.4 C5']
# [] ['BEETLE 1.4 C5']
# ['20723', '', 'BEETLE 1.4 C5']
# [] ['BEETLE 1.4 C5']
# ['7556', '', '']
# [] []
# ['639', '', '']
# [] []
# ['3176', '', '']
# [] []
# ['7255', '', '']
# [] []
# ['2312', '', '']
# [] []
# ['724', '', '']
# [] []
# ['1267', '', '']
# [] []
# ['925', '', '']
# [] []
# ['2313', '', '']
# [] []
# ['3185', '', '']
# [] []
# ['7158', '', '']
# [] []
# ['6362', '', '']
# [] []
# ['7471', '', '']
# [] []
# ['7472', '', '']
# [] []
# ['7473', '', '']
# [] []
# ['13834', '', '']
# [] []
# ['17116', '', 'BEETLE 2.0']
# [] ['BEETLE 2.0']
# ['19304', '', 'BEETLE 2.0']
# [] ['BEETLE 2.0']
# ['20724', '', '']
# [] []
# ['1966', '', '']
# [] []
# ['1967', '', '']
# [] []
# ['7269', '', '']
# [] []
# ['12512', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['12513', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['12514', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['20477', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['20478', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['22991', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['22992', '', 'PHAETON 3.0 FSI']
# [] ['PHAETON 3.0 FSI']
# ['7932', '', 'PHAETON 3.0 TDI']
# [] ['PHAETON 3.0 TDI']
# ['12515', '', 'PHAETON 3.0 TDI']
# [] ['PHAETON 3.0 TDI']
# ['1979', '', '']
# [] []
# ['2813', '', '']
# [] []
# ['5180', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['5187', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['5181', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['5182', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['7642', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['8521', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['8576', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['8577', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['12516', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['22993', '', 'PHAETON 3.6;PHAETON 3.6 C5']
# [] ['PHAETON 3.6', 'PHAETON 3.6 C5']
# ['1226', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['2205', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['5197', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['5198', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['7927', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['12517', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['16231', '', 'PHAETON 4.2']
# [] ['PHAETON 4.2']
# ['22612', '', 'PHAETON 4.2;PHAETON 4.2 C5']
# [] ['PHAETON 4.2', 'PHAETON 4.2 C5']
# ['376', '', '']
# [] []
# ['1980', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['2206', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['5199', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['5200', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['7924', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['12518', '', 'PHAETON 6.0']
# [] ['PHAETON 6.0']
# ['9126', '', 'SVW6440EGD;SVW6440GGD']
# [] ['SVW6440EGD', 'SVW6440GGD']
# ['14907', '', 'SVW6440QGD;SVW6440SGD']
# [] ['SVW6440QGD', 'SVW6440SGD']
# ['19817', '', 'SVW6440UGD;SVW6440XGD']
# [] ['SVW6440UGD', 'SVW6440XGD']
# ['9127', '', 'SVW6440EGD;SVW6440GGD']
# [] ['SVW6440EGD', 'SVW6440GGD']
# ['9129', '', 'SVW6440EGD;SVW6440GGD']
# [] ['SVW6440EGD', 'SVW6440GGD']
# ['14908', '', 'SVW6440EGD']
# [] ['SVW6440EGD']
# ['14910', '', 'SVW6440EGD']
# [] ['SVW6440EGD']
# ['14912', '', 'SVW6440EGD']
# [] ['SVW6440EGD']
# ['19818', '', 'SVW6440UGD;SVW6440XGD']
# [] ['SVW6440UGD', 'SVW6440XGD']
# ['19820', '', 'SVW6440UGD;SVW6440XGD']
# [] ['SVW6440UGD', 'SVW6440XGD']
# ['9128', '', 'SVW6440FGD']
# [] ['SVW6440FGD']
# ['9109', '', 'SVW6440FGD']
# [] ['SVW6440FGD']
# ['3766', '', 'SVW6440HGD;SVW6440PGD']
# [] ['SVW6440HGD', 'SVW6440PGD']
# ['14909', '', 'SVW6440JGD']
# [] ['SVW6440JGD']
# ['14911', '', 'SVW6440JGD']
# [] ['SVW6440JGD']
# ['14913', '', 'SVW6440KGD']
# [] ['SVW6440KGD']
# ['14502', '', 'SVW6440JGD']
# [] ['SVW6440JGD']
# ['14914', '', 'SVW6440KGD']
# [] ['SVW6440KGD']
# ['19939', '', 'SVW6440YGD;SVW6440JGD;SVW6440KGD;SVW6440VGD;SVW6440MGD;SVW6440PGD;SVW6440RGD;SVW6440TGD;SVW6440FGD;SVW6440HGD']
# [] ['SVW6440YGD', 'SVW6440JGD', 'SVW6440KGD', 'SVW6440VGD', 'SVW6440MGD', 'SVW6440PGD', 'SVW6440RGD', 'SVW6440TGD', 'SVW6440FGD', 'SVW6440HGD']
# ['19819', '', 'SVW6440VGD']
# [] ['SVW6440VGD']
# ['19821', '', 'SVW6440VGD']
# [] ['SVW6440VGD']
# ['19822', '', 'SVW6440VGD']
# [] ['SVW6440VGD']
# ['25112', '', 'SVW6453AGD;SVW6453KGD']
# [] ['SVW6453AGD', 'SVW6453KGD']
# ['25114', '', 'SVW6453AGD;SVW6453CGD;SVW6453KGD;SVW6453NGD']
# [] ['SVW6453AGD', 'SVW6453CGD', 'SVW6453KGD', 'SVW6453NGD']
# ['32033', '', 'SVW6453KGD']
# [] ['SVW6453KGD']
# ['25113', '', 'SVW6453BGD;SVW6453LGD']
# [] ['SVW6453BGD', 'SVW6453LGD']
# ['25115', '', 'SVW6453BGD;SVW6453LGD;SVW6453DGD;SVW6453PGD']
# [] ['SVW6453BGD', 'SVW6453LGD', 'SVW6453DGD', 'SVW6453PGD']
# ['25117', '', 'SVW6453BGD;SVW6453LGD;SVW6453FGD;SVW6453MGD;SVW6453DGD;SVW6453PGD']
# [] ['SVW6453BGD', 'SVW6453LGD', 'SVW6453FGD', 'SVW6453MGD', 'SVW6453DGD', 'SVW6453PGD']
# ['25116', '', 'SVW6453BGD;SVW6453LGD;SVW6453FGD;SVW6453MGD;SVW6453DGD;SVW6453PGD']
# [] ['SVW6453BGD', 'SVW6453LGD', 'SVW6453FGD', 'SVW6453MGD', 'SVW6453DGD', 'SVW6453PGD']
# ['32034', '', 'SVW6453PGD']
# [] ['SVW6453PGD']
# ['40102', '', 'SVW6453LGD;SVW6453MGD;SVW6453PGD;SVW6453BGD;SVW6453DGD;SVW6453FGD']
# [] ['SVW6453LGD', 'SVW6453MGD', 'SVW6453PGD', 'SVW6453BGD', 'SVW6453DGD', 'SVW6453FGD']
# ['32035', '', 'SVW6453PGD']
# [] ['SVW6453PGD']
# ['40103', '', 'SVW6453PGD']
# [] ['SVW6453PGD']
# ['32036', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['33630', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['32037', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['33631', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['35356', '', 'SVW6453SGD']
# [] ['SVW6453SGD']
# ['35357', '', 'SVW6453RGD']
# [] ['SVW6453RGD']
# ['40104', '', 'SVW6453QGD']
# [] ['SVW6453QGD']
# ['40105', '', 'SVW6453QGD']
# [] ['SVW6453QGD']
# ['35358', '', 'SVW6453MGD;SVW6453PGD;SVW6453SGD']
# [] ['SVW6453MGD', 'SVW6453PGD', 'SVW6453SGD']
# ['35359', '', 'SVW6453MGD;SVW6453PGD;SVW6453RGD']
# [] ['SVW6453MGD', 'SVW6453PGD', 'SVW6453RGD']
# ['40106', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['40107', '', 'SVW6453MGD;SVW6453PGD']
# [] ['SVW6453MGD', 'SVW6453PGD']
# ['32032', '', 'SVW6453ECD']
# [] ['SVW6453ECD']
# ['1641', '', 'SVW6440EBi']
# [] ['SVW6440EBi']
# ['1630', '', 'SVW6440EBi']
# [] ['SVW6440EBi']
# ['1632', '', 'SVW6440GBi']
# [] ['SVW6440GBi']
# ['1643', '', 'SVW6440GBi']
# [] ['SVW6440GBi']
# ['2269', '', 'SVW6440EBD']
# [] ['SVW6440EBD']
# ['3604', '', 'SVW6440NBi']
# [] ['SVW6440NBi']
# ['1631', '', 'SVW6440FBi']
# [] ['SVW6440FBi']
# ['1640', '', 'SVW6440PBD;SVW6440RBD;SVW6440RBi;SVW6440TBD;SVW6440VBD']
# [] ['SVW6440PBD', 'SVW6440RBD', 'SVW6440RBi', 'SVW6440TBD', 'SVW6440VBD']
# ['1633', '', 'SVW6440HBi']
# [] ['SVW6440HBi']
# ['1642', '', 'SVW6440PBD;SVW6440RBD;SVW6440RBi;SVW6440TBD;SVW6440VBD']
# [] ['SVW6440PBD', 'SVW6440RBD', 'SVW6440RBi', 'SVW6440TBD', 'SVW6440VBD']
# ['2270', '', 'SVW6440FBD']
# [] ['SVW6440FBD']
# ['2271', '', 'SVW6440HBD']
# [] ['SVW6440HBD']
# ['3605', '', 'SVW6440PBi']
# [] ['SVW6440PBi']
# ['3606', '', 'SVW6440VBD']
# [] ['SVW6440VBD']
# ['24611', '', 'SVW6453GED;SVW6453HED;SVW6453JED']
# [] ['SVW6453GED', 'SVW6453HED', 'SVW6453JED']
# ['32038', '', 'SVW6453JED;SVW6453HED']
# [] ['SVW6453JED', 'SVW6453HED']
# ['1542', '', 'SVW6440AAi']
# [] ['SVW6440AAi']
# ['1275', '', 'SVW6440AAi']
# [] ['SVW6440AAi']
# ['1449', '', 'SVW6440CAi;SVW6440CAD']
# [] ['SVW6440CAi', 'SVW6440CAD']
# ['1634', '', 'SVW6440AAi;SVW6440AAD']
# [] ['SVW6440AAi', 'SVW6440AAD']
# ['1662', '', 'SVW6440CAi;SVW6440CAD']
# [] ['SVW6440CAi', 'SVW6440CAD']
# ['2266', '', 'SVW6440AAi']
# [] ['SVW6440AAi']
# ['2268', '', 'SVW6440CAi;SVW6440CAD']
# [] ['SVW6440CAi', 'SVW6440CAD']
# ['3602', '', 'SVW6440JAi']
# [] ['SVW6440JAi']
# ['1448', '', 'SVW6440BAi']
# [] ['SVW6440BAi']
# ['1450', '', 'SVW6440DAi;SVW6440DAD']
# [] ['SVW6440DAi', 'SVW6440DAD']
# ['1663', '', 'SVW6440BAi;SVW6440BAD']
# [] ['SVW6440BAi', 'SVW6440BAD']
# ['1664', '', 'SVW6440DAi;SVW6440DAD']
# [] ['SVW6440DAi', 'SVW6440DAD']
# ['2267', '', 'SVW6440BAi']
# [] ['SVW6440BAi']
# ['3603', '', 'SVW6440KAi']
# [] ['SVW6440KAi']
# ['4308', '', 'SVW6440BAi;SVW6440KAi;SVW6440KAD;SVW6440BDD']
# [] ['SVW6440BAi', 'SVW6440KAi', 'SVW6440KAD', 'SVW6440BDD']
# ['1605', '', 'FV7165']
# [] ['FV7165']
# ['1606', '', 'FV6440B']
# [] ['FV6440B']
# ['1607', '', 'FV7165']
# [] ['FV7165']
# ['1608', '', 'FV6440B']
# [] ['FV6440B']
# ['1609', '', '']
# [] []
# ['1400', '', 'FV6440SDi']
# [] ['FV6440SDi']
# ['7889', '', '']
# [] []
# ['9302', '', '']
# [] []
# ['8678', '', '']
# [] []
# ['8680', '', '']
# [] []
# ['11799', '', '']
# [] []
# ['12793', '', '']
# [] []
# ['14856', '', '']
# [] []
# ['14730', '', '']
# [] []
# ['11433', '', '']
# [] []
# ['18003', '', '']
# [] []
# ['18011', '', '']
# [] []
# ['20486', '', '']
# [] []
# ['20487', '', '']
# [] []
# ['19239', '', '']
# [] []
# ['20521', '', '']
# [] []
# ['20522', '', '']
# [] []
# ['19592', '', '']
# [] []
# ['37806', '', '']
# [] []
# ['2602', '', '']
# [] []
# ['1382', '', '']
# [] []
# ['12165', '', '']
# [] []
# ['10308', '', '']
# [] []
# ['6062', '', '']
# [] []
# ['19073', '', 'GOLF R CJXBAD6501']
# [] ['GOLF R CJXBAD6501']
# ['20926', '', '']
# [] []
# ['31431', '', 'GOLF R DJHBAD7501']
# [] ['GOLF R DJHBAD7501']
# ['1834', '', '']
# [] []
# ['1770', '', '']
# [] []
# ['20643', '', '']
# [] []
# ['24377', '', '']
# [] []
# ['1866', '', '']
# [] []
# ['6930', '', '']
# [] []
# ['8832', '', '']
# [] []
# ['19719', '', '']
# [] []
# ['3297', '', '']
# [] []
# ['3298', '', '']
# [] []
# ['9676', '', '']
# [] []
# ['9677', '', '']
# [] []
# ['7797', '', '']
# [] []
# ['3957', '', '']
# [] []
# ['8712', '', '']
# [] []
# ['31127', '', 'FV7126BADBG']
# [] ['FV7126BADBG']
# ['27778', '', 'FV7126BADBG']
# [] ['FV7126BADBG']
# ['32457', '', 'FV7126BADBG']
# [] ['FV7126BADBG']
# ['40827', 'FV7126NAMBG;FV7126NAMDG', '']
# ['FV7126NAMBG', 'FV7126NAMDG'] []
# ['38346', 'FV7126NAMBG;FV7126NAMDG', '']
# ['FV7126NAMBG', 'FV7126NAMDG'] []
# ['40829', 'FV7126NAMBG;FV7126NAMDG', '']
# ['FV7126NAMBG', 'FV7126NAMDG'] []
# ['38348', 'FV7126NAMBG;FV7126NAMDG', '']
# ['FV7126NAMBG', 'FV7126NAMDG'] []
# ['40828', 'FV7126NADDG;FV7126NADBG', '']
# ['FV7126NADDG', 'FV7126NADBG'] []
# ['38347', 'FV7126NADDG;FV7126NADBG', '']
# ['FV7126NADDG', 'FV7126NADBG'] []
# ['40830', 'FV7126NADDG;FV7126NADBG', '']
# ['FV7126NADDG', 'FV7126NADBG'] []
# ['38349', 'FV7126NADDG;FV7126NADBG', 'FV7126NADDG']
# ['FV7126NADDG', 'FV7126NADBG'] ['FV7126NADDG']
# ['6108', '', 'FV7146TG']
# [] ['FV7146TG']
# ['6110', '', 'FV7146TG']
# [] ['FV7146TG']
# ['9027', '', 'FV7146TG']
# [] ['FV7146TG']
# ['8862', '', 'FV7146TG']
# [] ['FV7146TG']
# ['11908', '', 'FV7146FBMGG']
# [] ['FV7146FBMGG']
# ['11837', '', 'FV7146FBMGG']
# [] ['FV7146FBMGG']
# ['16964', '', 'FV7146FBMAG;FV7146FBMGG;FV7146FBMBG;FV7146FBMWG']
# [] ['FV7146FBMAG', 'FV7146FBMGG', 'FV7146FBMBG', 'FV7146FBMWG']
# ['19394', '', 'FV7146FBMWG']
# [] ['FV7146FBMWG']
# ['21295', '', 'FV7146FBMAG;FV7146FBMGG;FV7146FBMBG;FV7146FBMWG']
# [] ['FV7146FBMAG', 'FV7146FBMGG', 'FV7146FBMBG', 'FV7146FBMWG']
# ['16966', '', 'FV7146FBMAG;FV7146FBMGG;FV7146FBMBG;FV7146FBMWG']
# [] ['FV7146BBDBG']
# ['20924', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['27787', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['27779', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['32458', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['34608', '', 'FV7146BCDBB']
# [] ['FV7146BCDBB']
# ['32461', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['32459', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['32460', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['26853', '', 'FV7146BCDBG']
# [] ['FV7146BCDBG']
# ['37991', '', 'FV7146NBDBG']
# [] ['FV7146NBDBG']
# ['40831', '', '']
# [] []
# ['37709', '', '']
# [] []
# ['40832', '', '']
# [] []
# ['37976', '', 'FV7146NBDDG']
# [] ['FV7146NBDDG']
# ['40833', '', '']
# [] []
# ['40834', '', '']
# [] []
# ['38300', '', '']
# [] []
# ['2314', '', 'FV7166']
# [] ['FV7166']
# ['5797', '', 'FV7166G']
# [] ['FV7166G']
# ['4570', '', 'FV7166G']
# [] ['FV7166G']
# ['4587', '', 'FV7166G']
# [] ['FV7166G']
# ['9024', '', 'FV7166G']
# [] ['FV7166G']
# ['9026', '', 'FV7166G']
# [] ['FV7166G']
# ['11086', '', 'FV7166G']
# [] ['FV7166G']
# ['2315', '', 'FV7166AT']
# [] ['FV7166AT']
# ['5798', '', 'FV7166AT']
# [] ['FV7166AT']
# ['4586', '', 'FV7166AT']
# [] ['FV7166AT']
# ['4588', '', 'FV7166ATG']
# [] ['FV7166ATG']
# ['9025', '', 'FV7166ATG']
# [] ['FV7166ATG']
# ['8803', '', 'FV7166ATG']
# [] ['FV7166ATG']
# ['11087', '', 'FV7166ATG']
# [] ['FV7166ATG']
# ['11905', '', 'FV7166FAMGG']
# [] ['FV7166FAMGG']
# ['11907', '', 'FV7166FAMGG']
# [] ['FV7166FAMGG']
# ['16960', '', 'FV7166FAMAG;FV7166FAMGG;FV7166FAMWG']
# [] ['FV7166FAMAG', 'FV7166FAMGG', 'FV7166FAMWG']
# ['18253', '', 'FV7166FAMWG']
# [] ['FV7166FAMWG']
# ['21293', '', 'FV7166FAMAG;FV7166FAMGG;FV7166FAMWG']
# [] ['FV7166FAMAG', 'FV7166FAMGG', 'FV7166FAMWG']
# ['19200', '', 'FV7166FAMWG']
# [] ['FV7166FAMWG']
# ['16962', '', 'FV7166FAMAG;FV7166FAMGG;FV7166FAMWG']
# [] ['FV7166FAMAG', 'FV7166FAMGG', 'FV7166FAMWG']
# ['11906', '', 'FV7166FAAGG']
# [] ['FV7166FAAGG']
# ['11878', '', 'FV7166FAAGG']
# [] ['FV7166FAAGG']
# ['16961', '', 'FV7166FAAAG;FV7166FAAGG;FV7166FAAWG']
# [] ['FV7166FAAAG', 'FV7166FAAGG', 'FV7166FAAWG']
# ['19393', '', 'FV7166FAAWG']
# [] ['FV7166FAAWG']
# ['21294', '', 'FV7166FAAAG;FV7166FAAGG;FV7166FAAWG']
# [] ['FV7166FAAAG', 'FV7166FAAGG', 'FV7166FAAWG']
# ['19201', '', 'FV7166FAAWG']
# [] ['FV7166FAAWG']
# ['16963', '', 'FV7166FAAAG;FV7166FAAGG;FV7166FAAWG']
# [] ['FV7166FAAAG', 'FV7166FAAGG', 'FV7166FAAWG']
# ['22090', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['22091', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['27771', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['27770', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['32453', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['32455', '', 'FV7166BAMBG']
# [] ['FV7166BAMBG']
# ['22092', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['22093', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['27772', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['27773', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['32454', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['32456', '', 'FV7166BABBG']
# [] ['FV7166BABBG']
# ['2017', '', 'FV7186T']
# [] ['FV7186T']
# ['2134', '', 'FV7186T']
# [] ['FV7186T']
# ['3219', '', 'FV7186T']
# [] ['FV7186T']
# ['3220', '', 'FV7186T']
# [] ['FV7186T']
# ['2135', '', 'FV7186TATE']
# [] ['FV7186TATE']
# ['2018', '', 'FV7186TATE']
# [] ['FV7186TATE']
# ['3221', '', 'FV7186TATG']
# [] ['FV7186TATG']
# ['3222', '', 'FV7186TATE']
# [] ['FV7186TATE']
# ['4193', '', 'FV7186TG']
# [] ['FV7186TG']
# ['7761', '', 'FV7186TG']
# [] ['FV7186TG']
# ['9029', '', 'FV7186TG']
# [] ['FV7186TG']
# ['4148', '', 'FV7186TATG']
# [] ['FV7186TATG']
# ['7514', '', 'FV7186TATG']
# [] ['FV7186TATG']
# ['9030', '', 'FV7186TATG']
# [] ['FV7186TATG']
# ['11387', '', 'FV7186FCDWG']
# [] ['FV7186FCDWG']
# ['16969', '', 'FV7186FCDAG;FV7186FCDBG;FV7186FCDWG;FV7186FCDGG']
# [] ['FV7186FCDAG', 'FV7186FCDBG', 'FV7186FCDWG', 'FV7186FCDGG']
# ['19397', '', 'FV7186FCDWG']
# [] ['FV7186FCDWG']
# ['4589', '', 'FV7206G']
# [] ['FV7206G']
# ['4590', '', 'FV7206ATG']
# [] ['FV7206ATG']
# ['2132', '', 'FV7206']
# [] ['FV7206']
# ['2019', '', 'FV7206']
# [] ['FV7206']
# ['2133', '', 'FV7206AT']
# [] ['FV7206AT']
# ['2020', '', 'FV7206AT']
# [] ['FV7206AT']
# ['15467', '', 'FV7206FDDWG']
# [] ['FV7206FDDWG']
# ['26393', '', 'FV7206BDDBG']
# [] ['FV7206BDDBG']
# ['32462', '', 'FV7206BDDBG']
# [] ['FV7206BDDBG']
# [] ['FV7207E']
# ['39429', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['36588', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['39430', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['36589', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['39431', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['36590', 'FV7207BEDBG', 'FV7207BDDBG']
# ['FV7207BEDBG'] ['FV7207BDDBG']
# ['5013', '', 'FV7207TDQG']
# [] ['FV7207TDQG']
# ['4937', '', 'FV7207TDQG']
# [] ['FV7207TDQG']
# ['7637', '', 'FV7207TDQG']
# [] ['FV7207TDQG']
# ['7638', '', 'FV7207TDQG']
# [] ['FV7207TDQG']
# ['12314', '', 'FV7207TFATG']
# [] ['FV7207TFATG']
# ['10290', '', 'FV7207TFATG']
# [] ['FV7207TFATG']
# ['12310', '', 'FV7207FCDWG;FV7207TFATG;FV7207FCDAG;FV7207FCDBG']
# [] ['FV7207FCDWG', 'FV7207TFATG', 'FV7207FCDAG', 'FV7207FCDBG']
# ['10291', '', 'FV7207TFATG']
# [] ['FV7207TFATG']
# ['12311', '', 'FV7207FCDWG;FV7207TFATG;FV7207FCDAG;FV7207FCDBG']
# [] ['FV7207FCDWG', 'FV7207TFATG', 'FV7207FCDAG', 'FV7207FCDBG']
# ['16358', '', 'FV7207FCDWG']
# [] ['FV7207FCDWG']
# ['16359', '', 'FV7207FCDWG']
# [] ['FV7207FCDWG']
# ['16360', '', 'FV7207FCDWG']
# [] ['FV7207FCDWG']
# ['20272', '', 'FV7207FCDAG;FV7207FCDBG']
# [] ['FV7207FCDAG', 'FV7207FCDBG']
# ['22265', '', 'FV7207FCDBG']
# [] ['FV7207FCDBG']
# ['20273', '', 'FV7207FCDAG;FV7207FCDBG']
# [] ['FV7207FCDAG', 'FV7207FCDBG']
# ['22267', '', 'FV7207FCDBG']
# [] ['FV7207FCDBG']
# ['20274', '', 'FV7207FCDAG;FV7207FCDBG']
# [] ['FV7207FCDAG', 'FV7207FCDBG']
# ['22266', '', 'FV7207FCDBG']
# [] ['FV7207FCDBG']
# ['25169', '', 'FV7207FCDBG']
# [] ['FV7207FCDBG']
# ['25170', '', 'FV7207FCDBG']
# [] ['FV7207FCDBG']
# ['2693', '', 'FV7207TATG']
# [] ['FV7207TATG']
# ['3794', '', 'FV7207TATG']
# [] ['FV7207TATG']
# ['26933', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['26913', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['26202', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['32003', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['34170', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['31860', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['32004', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['39432', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['36591', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['39433', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['36592', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['39434', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['36593', '', 'FV7207BCDBG']
# [] ['FV7207BCDBG']
# ['11428', '', 'FV7307FDDGG;FV7307FDDWG']
# [] ['FV7307FDDGG', 'FV7307FDDWG']
# ['18775', '', 'FV7307FDDGG;FV7307FDDWG;FV7307FDDAG;FV7307FDDBG']
# [] ['FV7307FDDGG', 'FV7307FDDWG', 'FV7307FDDAG', 'FV7307FDDBG']
# ['4429', '', '']
# [] []
# ['8260', '', '']
# [] []
# ['7493', '', '']
# [] []
# ['9809', '', '']
# [] []
# ['21696', '', '']
# [] []
# ['23892', '', '']
# [] []
# ['23225', '', '']
# [] []
# ['2830', '', '']
# [] []
# ['2829', '', '']
# [] []
# ['28898', '', '']
# [] []
# ['10801', '', 'SVW71410MR;SVW71410AR;SVW71410GR;SVW71410CR;SVW71410PR']
# [] ['SVW71410MR', 'SVW71410AR', 'SVW71410GR', 'SVW71410CR', 'SVW71410PR']
# ['14448', '', 'SVW71410MR']
# [] ['SVW71410MR']
# ['14449', '', 'SVW71410MR']
# [] ['SVW71410MR']
# ['18293', '', 'SVW71410GR']
# [] ['SVW71410GR']
# ['18295', '', 'SVW71410GR']
# [] ['SVW71410GR']
# ['23507', '', 'SVW71410CR']
# [] ['SVW71410CR']
# ['23508', '', 'SVW71410CR']
# [] ['SVW71410CR']
# ['10546', '', 'SVW71410NR;SVW71410BR;SVW71410DR;SVW71410ER;SVW71410JR;SVW71410RR;SVW71410SR']
# [] ['SVW71410NR', 'SVW71410BR', 'SVW71410DR', 'SVW71410ER', 'SVW71410JR', 'SVW71410RR', 'SVW71410SR']
# ['14450', '', 'SVW71410NR']
# [] ['SVW71410NR']
# ['14444', '', 'SVW71410JR']
# [] ['SVW71410JR']
# ['18297', '', 'SVW71410RR']
# [] ['SVW71410RR']
# ['18300', '', 'SVW71410JR']
# [] ['SVW71410JR']
# ['23509', '', 'SVW71410DR']
# [] ['SVW71410DR']
# ['23510', '', 'SVW71410ER']
# [] ['SVW71410ER']
# ['25073', '', 'SVW71410AL']
# [] ['SVW71410AL']
# ['25074', '', 'SVW71410BL']
# [] ['SVW71410BL']
# ['29314', '', 'SVW71410BL']
# [] ['SVW71410BL']
# ['29315', '', 'SVW71410BL']
# [] ['SVW71410BL']
# ['36576', '', 'SVW71423CT']
# [] ['SVW71423CT']
# ['36582', '', 'SVW71423CT']
# [] ['SVW71423CT']
# ['36577', '', 'SVW71423CT']
# [] ['SVW71423CT']
# ['36583', '', 'SVW71423CT']
# [] ['SVW71423CT']
# ['29011', '', 'GAC7000BEVH0A']
# [] ['GAC7000BEVH0A']
# ['34920', '', 'GAH7000BEVH0A']
# [] ['GAH7000BEVH0A']
# ['35562', '', '']
# [] []
# ['35563', '', '']
# [] []
# ['35564', '', '']
# [] []
# ['35560', '', '']
# [] []
# ['38032', '', '']
# [] []
# ['41088', '', '']
# [] []
# ['39146', '', '']
# [] []
# ['41089', '', '']
# [] []
# ['38033', '', '']
# [] []
# ['38034', '', '']
# [] []
# ['41090', '', '']
# [] []
# ['38035', '', '']
# [] []
# ['38814', '', '']
# [] []
# ['41369', '', '']
# [] []
# ['41368', '', '']
# [] []
# ['41370', '', '']
# [] []
# ['41371', '', '']
# [] []
# ['33330', '', 'SC7149BA5;SC7149BY4;SC7149BYB5;SC7149B4;SC7149B5;SC7149BYB4;SC7149BYBB5;SC7149BB5;GHK7140A']
# [] ['SC7149BA5', 'SC7149BY4', 'SC7149BYB5', 'SC7149B4', 'SC7149B5', 'SC7149BYB4', 'SC7149BYBB5', 'SC7149BB5', 'GHK7140A']
# ['33331', '', 'SC7149BA5;SC7149BY4;SC7149BYB5;SC7149B4;SC7149B5;SC7149BYB4;SC7149BYBB5;SC7149BB5;GHK7140A']
# [] ['SC7149BA5', 'SC7149BY4', 'SC7149BYB5', 'SC7149B4', 'SC7149B5', 'SC7149BYB4', 'SC7149BYBB5', 'SC7149BB5', 'GHK7140A']
# ['33327', '', 'GHK7140']
# [] ['GHK7140']
# ['33329', '', 'GHK7140']
# [] ['GHK7140']
# ['37260', '', '']
# [] []
# ['37261', '', '']
# [] []
# ['37262', '', '']
# [] []
# ['35092', '', '']
# [] []
# ['34535', '', '']
# [] []
# ['33413', '', '']
# [] []
# ['35216', 'SQR5020XXYF01', 'SQR6472F012']
# ['SQR5020XXYF01'] ['SQR6472F012']
# ['35217', 'SQR5020XXYF01', 'SQR6472F012']
# ['SQR5020XXYF01'] ['SQR6472F012']
# ['35218', 'SQR5020XXYF01', 'SQR6472F012']
# ['SQR5020XXYF01'] ['SQR6472F012']
# ['35219', 'SQR5020XXYF01', 'SQR6472F012']
# ['SQR5020XXYF01'] ['SQR6472F012']
# ['35220', 'SQR5021XXYF01', 'SQR6471F01T2']
# ['SQR5021XXYF01'] ['SQR6471F01T2']
# ['35222', 'SQR5021XXYF01', 'SQR6471F01T2']
# ['SQR5021XXYF01'] ['SQR6471F01T2']
# ['35223', 'SQR5021XXYF01', 'SQR6471F01T2']
# ['SQR5021XXYF01'] ['SQR6471F01T2']
# ['35221', 'SQR5021XXYF01', 'SQR6471F01T2']
# ['SQR5021XXYF01'] ['SQR6471F01T2']
# ['40559', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['40561', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['40562', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['40563', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['40560', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', 'SQR6470F01T9']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] ['SQR6470F01T9']
# ['41337', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['41338', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['41339', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['41336', 'SQR6471F01T9;SQR6472F01T9;SQR6473F01T9', '']
# ['SQR6471F01T9', 'SQR6472F01T9', 'SQR6473F01T9'] []
# ['41331', 'SQR6470F019;SQR6471F019', '']
# ['SQR6470F019', 'SQR6471F019'] []
# ['41335', 'SQR6470F019;SQR6471F019', '']
# ['SQR6470F019', 'SQR6471F019'] []
# ['41332', 'SQR6470F019;SQR6471F019', '']
# ['SQR6470F019', 'SQR6471F019'] []
# ['41333', 'SQR6470F019;SQR6471F019', '']
# ['SQR6470F019', 'SQR6471F019'] []
# ['41334', 'SQR6470F019;SQR6471F019', '']
# ['SQR6470F019', 'SQR6471F019'] []
# ['37490', '', '']
# [] []
# ['37513', '', '']
# [] []
# ['37514', '', '']
# [] []
# ['37517', '', '']
# [] []
# ['37518', '', '']
# [] []
# ['37493', '', '']
# [] []
# ['37519', '', '']
# [] []
# ['37520', '', '']
# [] []
# ['37491', '', '']
# [] []
# ['37515', '', '']
# [] []
# ['37516', '', 'SQR6481F082']
# [] ['SQR6481F082']
# ['37492', '', '']
# [] []
# ['37496', '', '']
# [] []
# ['37523', '', '']
# [] []
# ['37524', '', '']
# [] []
# ['37497', '', 'SQR6482F08T2']
# [] ['SQR6482F08T2']
# ['37525', '', '']
# [] []
# ['37526', '', '']
# [] []
# ['37470', '', 'SQR6482F08T2']
# [] ['SQR6482F08T2']
# ['37527', '', '']
# [] []
# ['37528', '', '']
# [] []
# ['37495', '', '']
# [] []
# ['37521', '', '']
# [] []
# ['37522', '', '']
# [] []
# ['40524', 'SQR6480F08T9;SQR6482F08T9;SQR6483F08T9;SQR6481F08T9', '']
# ['SQR6480F08T9', 'SQR6482F08T9', 'SQR6483F08T9', 'SQR6481F08T9'] []
# ['41308', 'SQR6480F08T9;SQR6482F08T9;SQR6483F08T9;SQR6481F08T9', '']
# ['SQR6480F08T9', 'SQR6482F08T9', 'SQR6483F08T9', 'SQR6481F08T9'] []
# ['40526', 'SQR6480F08T9;SQR6482F08T9;SQR6483F08T9;SQR6481F08T9', '']
# ['38772', '', '']
# [] []
# ['34384', '', '']
# [] []
# ['35600', '', '']
# [] []
# ['35601', '', '']
# [] []
# ['34386', '', '']
# [] []
# ['35602', '', '']
# [] []
# ['38863', '', '']
# [] []
# ['38868', '', '']
# [] []
# ['38864', '', '']
# [] []
# ['38865', '', '']
# [] []
# ['38866', '', '']
# [] []
# ['38867', '', '']
# [] []
# ['1006228', '', '']
# [] []
# ['1006691', '', '']
# [] []
# ['41530', '', '']
# [] []
# ['41525', '', '']
# [] []
# ['41527', '', '']
# [] []
# ['41528', '', '']
# [] []
# ['33130', '', 'GAC6450CHEVA5;GAC6450CHEVA5A;GMC6450ACHEV;GMC6450BCHEV']
# [] ['GAC6450CHEVA5', 'GAC6450CHEVA5A', 'GMC6450ACHEV', 'GMC6450BCHEV']
# ['30278', '', 'GAC6450CHEVA5;GAC6450CHEVA5A;GMC6450ACHEV;GMC6450BCHEV']
# [] ['GAC6450CHEVA5', 'GAC6450CHEVA5A', 'GMC6450ACHEV', 'GMC6450BCHEV']
# ['35138', '', 'GMC6450BCHEV']
# [] ['GMC6450BCHEV']
# ['35139', '', 'GAC6450CHEVA5;GAC6450CHEVA5A;GMC6450ACHEV;GMC6450BCHEV']
# [] ['GAC6450CHEVA5', 'GAC6450CHEVA5A', 'GMC6450ACHEV', 'GMC6450BCHEV']
# ['35594', '', 'GTM6450GBEV']
# [] ['GTM6450GBEV']
# ['35603', '', '']
# [] []
# ['40739', '', '']
# [] []
# ['38986', '', '']
# [] []
# ['35785', '', '']
# [] []
# ['35786', '', '']
# [] []
# ['36979', '', '']
# [] []
# ['36335', '', '']
# [] []
# ['41455', '', '']
# [] []
# ['41456', '', '']
# [] []
# ['40811', '', '']
# [] []
# ['42055', '', '']
# [] []
# ['41925', '', '']
# [] []
# ['35664', '', 'CC7001CE02ABEV']
# [] ['CC7001CE02ABEV']
# ['36987', '', 'CC7001CE03BEV']
# [] ['CC7001CE03BEV']
# ['33394', '', 'CC7001CE02ABEV']
# [] ['CC7001CE02ABEV']
# ['36992', '', 'CC7001CE03BEV']
# [] ['CC7001CE03BEV']
# ['35665', '', 'CC7001CE02ABEV']
# [] ['CC7001CE02ABEV']
# ['36993', '', 'CC7001CE03BEV']
# [] ['CC7001CE03BEV']
# ['39199', '', '']
# [] []
# ['41416', '', '']
# [] []
# ['36640', '', 'CC7000ZM01BEV']
# [] ['CC7000ZM01BEV']
# ['37380', '', 'CC7000ZM00ABEV']
# [] ['CC7000ZM00ABEV']
# ['41328', '', '']
# [] []
# ['37388', '', 'CC7000ZM00ABEV']
# [] ['CC7000ZM00ABEV']
# ['38486', '', '']
# [] []
# ['36641', '', 'CC7000ZM01BEV']
# [] ['CC7000ZM01BEV']
# ['37387', '', 'CC7000ZM01BEV']
# [] ['CC7000ZM01BEV']
# ['36522', '', 'CC7000ZM00ABEV']
# [] ['CC7000ZM00ABEV']
# ['34843', '', '']
# [] []
# ['34844', '', '']
# [] []
# ['31341', '', '']
# [] []
# ['31801', '', '']
# [] []
# ['31802', '', '']
# [] []
# ['31800', '', '']
# [] []
# ['39304', '', '']
# [] []
# ['39305', '', '']
# [] []
# ['39306', '', '']
# [] []
# ['35102', '', '']
# [] []
# ['35103', '', '']
# [] []
# ['35104', '', '']
# [] []
# ['35033', '', '']
# [] []
# ['1006525', '', '']
# [] []
# ['1006524', '', '']
# [] []
# ['1008258', '', '']
# [] []
# ['38851', '', '']
# [] []
# ['35875', '', 'JML6472A62']
# [] ['JML6472A62']
# ['35876', '', 'JML6472A62']
# [] ['JML6472A62']
# ['35877', '', 'JML6472A62']
# [] ['JML6472A62']
# ['35861', '', 'JML6472A62']
# [] ['JML6472A62']
# ['38883', 'JML6452AA1', '']
# ['JML6452AA1'] []
# ['39147', 'JML6452AA1', '']
# ['JML6452AA1'] []
# ['39150', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['35910', 'JML6452AA2', 'JML6452A52']
# ['JML6452AA2'] ['JML6452A52']
# ['39151', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['38887', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['39152', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['38884', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['39148', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['38885', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['39149', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['38886', 'JML6452AA2', '']
# ['JML6452AA2'] []
# ['37417', '', '']
# [] []
# ['37418', '', '']
# [] []
# ['38902', '', '']
# [] []
# ['36809', '', '']
# [] []
# ['37315', '', 'JNJ6450K;JNJ6450;JNJ6450J;JNJ6450JK']
# [] ['JNJ6450K', 'JNJ6450', 'JNJ6450J', 'JNJ6450JK']
# ['38162', 'JML6450AD1;JML6450AE1', 'JNJ6450Q1K;JNJ6450Q1JK;JNJ6450Q3K']
# ['JML6450AD1', 'JML6450AE1'] ['JNJ6450Q1K', 'JNJ6450Q1JK', 'JNJ6450Q3K']
# ['41112', 'JML6450AD1;JML6450AE1', '']
# ['JML6450AD1', 'JML6450AE1'] []
# ['34929', '', '']
# [] []
# ['32265', '', '']
# [] []
# ['36085', '', '']
# [] []
# ['36086', '', '']
# [] []
# ['36087', '', '']
# [] []
# ['35973', '', '']
# [] []
# ['36214', '', '']
# [] []
# ['38634', '', '']
# [] []
# ['36400', '', '']
# [] []
# ['36399', '', '']
# [] []
# ['39828', '', '']
# [] []
# ['38502', '', '']
# [] []
# ['38361', '', '']
# [] []
# ['37103', '', 'SQR6480M32TT9']
# [] ['SQR6480M32TT9']
# ['38836', '', '']
# [] []
# ['37820', '', '']
# [] []
# ['38503', '', '']
# [] []
# ['41439', 'SQR6450T1CT9', '']
# ['SQR6450T1CT9'] []
# ['41440', 'SQR6450T1CT9', '']
# ['SQR6450T1CT9'] []
# ['41351', 'SQR6450T1CT9', '']
# ['SQR6450T1CT9'] []
# ['41270', 'SQR6450T1CT9', '']
# ['SQR6450T1CT9'] []
# ['1006967', '', '']
# [] []
# ['37704', '', '']
# [] []
# ['37705', '', '']
# [] []
# ['41224', 'FV7150BAMCG', '']
# ['FV7150BAMCG'] []
# ['41225', 'FV7150BAMCG', '']
# ['FV7150BAMCG'] []
# ['41822', 'FV7150BABCG', '']
# ['FV7150BABCG'] []
# ['37952', 'FV7150BABCG', '']
# ['FV7150BABCG'] []
# ['40821', 'FV7140LAMDG', '']
# ['FV7140LAMDG'] []
# ['41217', 'FV7140LAMDG', '']
# ['FV7140LAMDG'] []
# ['41219', 'FV7140LAADG', '']
# ['FV7140LAADG'] []
# ['37953', 'FV7140LAADG', '']
# ['FV7140LAADG'] []
# ['41218', 'FV7140LAADG', '']
# ['FV7140LAADG'] []
# ['38857', '', '']
# [] []
# ['38858', '', '']
# [] []
# ['39753', '', '']
# [] []
# ['38132', '', '']
# [] []
# ['1007669', '', '']
# [] []
# ['39711', '', '']
# [] []
# ['39708', '', '']
# [] []
# ['41788', '', '']
# [] []
# ['41113', '', '']
# [] []
# ['38722', '', '']
# [] []
# ['41789', '', '']
# [] []
# ['41790', '', '']
# [] []
# ['38723', '', '']
# [] []
# ['41794', '', '']
# [] []
# ['41791', '', '']
# [] []
# ['41792', '', '']
# [] []
# ['38724', '', '']
# [] []
# ['41793', '', '']
# [] []
# ['19885', '', 'DHG30E52WA8L']
# [] ['DHG30E52WA8L']
# ['19886', '', 'DHG30E52WA8L']
# [] ['DHG30E52WA8L']
# ['19909', '', '']
# [] []
# ['19887', '', 'DHG30E52WA8H']
# [] ['DHG30E52WA8H']
# ['19910', '', 'DHG30E54WA8L']
# [] ['DHG30E54WA8L']
# ['19911', '', 'DHG30E54WA8L']
# [] ['DHG30E54WA8L']
# ['19805', '', '']
# [] []
# ['19912', '', '']
# [] []
# ['19888', '', 'DHG33E52WA8L']
# [] ['DHG33E52WA8L']
# ['19889', '', 'DHG33E52WA8H']
# [] ['DHG33E52WA8H']
# ['19913', '', 'DHG33E54WA8']
# [] ['DHG33E54WA8']
# ['19914', '', 'DHG33E54WA8']
# [] ['DHG33E54WA8']
# ['38673', '', '']
# [] []
# ['38674', '', '']
# [] []
# ['38360', '', '']
# [] []
# ['36331', '', '']
# [] []
# ['38675', '', '']
# [] []
# ['38676', '', '']
# [] []
# ['39136', '', '']
# [] []
# ['39137', '', '']
# [] []
# ['39138', '', '']
# [] []
# ['39139', '', '']
# [] []
# ['41800', '', '']
# [] []
# ['39246', '', '']
# [] []
# ['1007521', '', '']
# [] []
# ['41646', '', '']
# [] []
# ['39707', '', '']
# [] []
# ['40826', '', '']
# [] []
# ['37275', '', '']
# [] []
# ['1007915', '', '']
# [] []
# ['1007916', '', '']
# [] []
# ['41378', '', '']
# [] []
# ['41379', '', '']
# [] []
# ['41380', '', '']
# [] []
# ['20488', '', '']
# [] []

# %%
a = ['cc','aa','bb','dd']
b = ['aa','bb']
c = a + b
d = list(set(c))
print(d)
d.sort()
print(d)
# Out:
# ['cc', 'dd', 'aa', 'bb']
# ['aa', 'bb', 'cc', 'dd']
