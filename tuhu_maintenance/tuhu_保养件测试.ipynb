# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver

url = 'https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle=%7B%22Brand%22%3A%22A+-+%E5%AE%89%E9%A9%B0%22%2C%22VehicleId%22%3A%22VE-ACXB%22%2C%22PaiLiang%22%3A%222.8T-%E6%9F%B4%E6%B2%B9%22%2C%22Nian%22%3A%222011%22%2C%22Tid%22%3A%22%22%2C%22Properties%22%3Anull%7D'
url = 'https://item.tuhu.cn/Car/SelectVehicleSalesName?callback=__GetCarBrands__&VehicleID=VE-LSG-EXCELLEGX&PaiLiang=1.3T&Nian=2018&_=1571106992302'

data = {
    "vehicle":{
        "Brand":"B - 别克","Vehicle":"阅朗-上汽通用别克",
        "FuelType":"",
        "Nian":"2018",
        "OnRoadTime":None,
        "Pailiang":"1.3T",
        "Properties":[],
        "SalesName":"2019款 1.3T 手自一体 互联旗舰版（国V排放）",
        "Tid":"118058",
        "VehicleId":"VE-LSG-EXCELLEGX",
        "CarID":"{4669fc2f-3c6c-4603-b4f3-76332874f80e}",
        "BuyYear":None,
        "BuyMonth":None,
        "Vehicle":"阅朗-上汽通用别克",
        "TotalMileage":0,
        "LastBaoYangKM":0,
        "CartypeDescription":" 别克 阅朗 1.3T 2018年产 2019款 1.3T 手自一体 互联旗舰版（国V排放）",
        "CartypeOther":None,
        "CarNumber":"",
        "Classno":None,
        "Engineno":None,
        "Carno_City":None,
        "Carno_Province":None,
        "LastBaoYangTime":"0001-01-01T00:00:00",
        "IsDefaultCar":True,
        "LIYANGID":None,
        "TireSizeForSingle":None,
        "Registrationtime":None
    },
    "baoyangType":"jiyou",
    "pid":"OL-MO-S1000-5W30|1"
}
headers = {
    "authority":"by.tuhu.cn",
    "method":"POST",
    "path":"/change/ChangeProduct.html",
    "scheme":"https",
    "accept":"*/*",
    "accept-encoding":"gzip, deflate, br",
    "accept-language":"zh-CN,zh;q=0.9",
    "x-requested-with":"XMLHttpRequest",
    "content-type":"application/x-www-form-urlencoded; charset=UTF-8",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36",
    "origin":"https://by.tuhu.cn",
    "referer":"https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html",
    "cookie": "_um_deti=e315e79cd3fb4fdabf9bd755c80df98d7; sajssdk_2015_cross_new_user=1; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216dce2bed6e513-0c83faac0cfe4e-c5f6652-2073600-16dce2bed6f309%22%2C%22%24device_id%22%3A%2216dce2bed6e513-0c83faac0cfe4e-c5f6652-2073600-16dce2bed6f309%22%2C%22props%22%3A%7B%22%24latest_referrer%22%3A%22%22%2C%22%24latest_referrer_host%22%3A%22%22%2C%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%7D; thzzWebsite=1571122048-a1f84e9331edc9db; clicksession=1571122048-908e332429de0c37; shoppingCart_quantity=0; city=831%7c%e5%b9%bf%e4%b8%9c%e7%9c%81%7c1%7c7%7c%e5%b9%bf%e5%b7%9e%e5%b8%82%7c1; shopcover=; Qs_lvt_73951=1571122048; Qs_pv_73951=1882710574161103000; defaultCar=0%7CVE-LSG-EXCELLEGX%7CB%20-%20%E5%88%AB%E5%85%8B%7C%E9%98%85%E6%9C%97-%E4%B8%8A%E6%B1%BD%E9%80%9A%E7%94%A8%E5%88%AB%E5%85%8B%7C1.3T%7C2018%7C205%2F55R16%7C%7C%7C%7C118058%7C%7Chttps%3A%2F%2Fimg1.tuhu.org%2FImages%2FLogo%2Fbieke.png%40100Q.png%3BProperties%3D%5B%5D%3BTid%3D118058%3BSalesName%3D2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDVI%E6%8E%92%E6%94%BE%EF%BC%89; Hm_lvt_cec8ce2d875c5cc615e9bfdf73d4e2fd=1571122049; Hm_lpvt_cec8ce2d875c5cc615e9bfdf73d4e2fd=1571122049"
}
url = 'https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html?Tid=118058&SalesName=2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDVI%E6%8E%92%E6%94%BE%EF%BC%89'
#url = 'https://by.tuhu.cn/change/ChangeProduct.html'
url = 'https://by.tuhu.cn/change/ChangeProduct.html'

response = requests.post(url=url,data=data,headers=headers).content.decode('utf-8')
#response = requests.get(url).content.decode('utf-8')
# bsObj = BeautifulSoup(response.decode('utf-8'),'lxml')
print(response)

# %%
''' 
PART1
模拟浏览器访问具体销售型，遍历点击所有保养项目
获取每个具体项目的bytype,data_pid
方便后续requests直接获取销售型每个具体bytype的所有商品信息
'''
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.parse

# url = 'https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html'
url = 'https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html?Tid=118058&SalesName=2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDVI%E6%8E%92%E6%94%BE%EF%BC%89'
url = 'https://by.tuhu.cn/baoyang/VE-LBV-118i/pl1.5T-n2017.html?Tid=109354&SalesName=2017%E6%AC%BE%201.5T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E8%AE%BE%E8%AE%A1%E5%A5%97%E8%A3%85%E5%9E%8B'
url = 'https://by.tuhu.cn/baoyang/VE-LBV-118i/pl1.5T-n2017.html?Tid=109354&SalesName=2017%E6%AC%BE%201.5T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E8%AE%BE%E8%AE%A1%E5%A5%97%E8%A3%85%E5%9E%8B'
options = webdriver.ChromeOptions()
options.add_argument('User-Agent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36"')
# options.add_argument('referer="https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html?Tid=118058&SalesName=2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDV%E6%8E%92%E6%94%BE%EF%BC%89"')
# options.add_argument('Origin="https://www.tuhu.cn"')
# options.add_argument('cookie="thzzWebsite=1570443975-a614d3f45423abc7; shoppingCart_quantity=0; city=831%7c%e5%b9%bf%e4%b8%9c%e7%9c%81%7c1%7c7%7c%e5%b9%bf%e5%b7%9e%e5%b8%82%7c1; NTKF_T2D_CLIENTID=guest4A2511CE-7610-93DF-9D3B-A8F76AD2CA29; deviceid=8715cc9e-dc15-42b2-bb66-9a777eaac5c0; _um_deti=2aae79979bd74e40b71d54a513ae2a306; HistoryProduct=OL-MO-ONE-5W30-1%7C%2CBD-FLD-SCPAN%7C53; _um_deti=2aae79979bd74e40b71d54a513ae2a306; sem=t=637066717214335283&c=2909&k=%e9%80%94%e8%99%8e&id=201910141742018439; shopcover=; Hm_lvt_cec8ce2d875c5cc615e9bfdf73d4e2fd=1570497850,1571046117,1571046122,1571058384; sensorsdata2015jssdkcross=%7B%22distinct_id%22%3A%2216da5c156fa1b7-0f21153ef3030d-6c50702b-2073600-16da5c156fb260%22%2C%22%24device_id%22%3A%2216da5c156fa1b7-0f21153ef3030d-6c50702b-2073600-16da5c156fb260%22%2C%22props%22%3A%7B%22%24latest_referrer%22%3A%22%22%2C%22%24latest_referrer_host%22%3A%22%22%2C%22%24latest_traffic_source_type%22%3A%22%E7%9B%B4%E6%8E%A5%E6%B5%81%E9%87%8F%22%2C%22%24latest_search_keyword%22%3A%22%E6%9C%AA%E5%8F%96%E5%88%B0%E5%80%BC_%E7%9B%B4%E6%8E%A5%E6%89%93%E5%BC%80%22%7D%7D; Qs_lvt_73951=1571045864%2C1571046116%2C1571046121%2C1571058383%2C1571104088; ASP.NET_SessionId=c3hleje24xbuu31vter4zzz4; carHistoryQuantity=0; .AspNet.Cookies=a3g9Xf1xlOgbzYDv_iA3AGd1M6NE7A-cvkz-hgdsirQoIIZo26_ZnF-5RCR35ybBdcUV0ulvKMZEE1PVkkM5_JiSenkc706CuqS7ltkLOGWn9hpC-T7ReBkhZ5QKiC9NAehb_H1V01PXVIgmyLm8GNr6IZP676lzalsHuZvOgS1PaCHGQ7TDxRE1bJp3-bSBiyC9Fg; __utma=86961565.894046589.1571104696.1571104696.1571104696.1; __utmc=86961565; __utmz=86961565.1571104696.1.1.utmcsr=by.tuhu.cn|utmccn=(referral)|utmcmd=referral|utmcct=/baoyang/VE-VOLS07AK/pl1.4L-n2010.html; nTalk_CACHE_DATA={uid:kf_9739_ISME9754_5beea335-9213-413e-96e3-559e2b6042e4,tid:1571104695500470}; clicksession=1571107787-63f7e6f4f8257729; Qs_pv_73951=4424222182934315500%2C2954389000883785000%2C3318497451687848000%2C4600933715983230500%2C1837565234483515400; Hm_lpvt_cec8ce2d875c5cc615e9bfdf73d4e2fd=1571108188; defaultCar=0%7CVE-LSG-EXCELLEGX%7CB%20-%20%E5%88%AB%E5%85%8B%7C%E9%98%85%E6%9C%97-%E4%B8%8A%E6%B1%BD%E9%80%9A%E7%94%A8%E5%88%AB%E5%85%8B%7C1.3T%7C2018%7C205%2F55R16%7C%7C%7C%7C118058%7C2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDV%E6%8E%92%E6%94%BE%EF%BC%89%7Chttps%3A%2F%2Fimg1.tuhu.org%2FImages%2FLogo%2Fbieke.png%40100Q.png%3BProperties%3D%5B%5D%3BTid%3D118058%3BSalesName%3D2019%E6%AC%BE%201.3T%20%E6%89%8B%E8%87%AA%E4%B8%80%E4%BD%93%20%E4%BA%92%E8%81%94%E6%97%97%E8%88%B0%E7%89%88%EF%BC%88%E5%9B%BDV%E6%8E%92%E6%94%BE%EF%BC%89"')
# options.add_argument('-user-data-dir="C:/Users/84141/AppData/Local/Google/Chrome/User Data/Default"')

driver = webdriver.Chrome(chrome_options=options)

driver.maximize_window()

# 中文网址转码
VehicledId='VE-AADQ5ADJK'
PaiLiang='3.0T(45TFSI)'
Nian='2013'
Tid='3109'
SalesName='2013款 3.0T 手自一体 45TFSI Quattro 四驱 越野版'
url_zh = 'https://by.tuhu.cn/baoyang/%s/pl%s-n%s.html?Tid=%s&SalesName=%s' %(VehicledId,PaiLiang,Nian,Tid,SalesName)

url = urllib.parse.quote(url_zh,':/?=&()')

driver.get(url)

# 判断保养项目是否存在
package_baoyangExist = driver.find_elements_by_xpath('.//div[@id="package_baoyang"]')
if package_baoyangExist:
    pass
else:
    print('传参有误')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:23: DeprecationWarning: use options instead of chrome_options

# %%
import time
'''
PART2
（1）访问目标网页时，默认只是勾选小保养保养项目，单独获取bytype,data_pid及HTML
（2）遍历点击所有保养项目，最后检查是否只有小保养未被勾选，获取除小保养外，所有保养项目bytype,data_pid及HTML
'''
# 1.首先获取小保养信息
inventory_left = driver.find_element_by_xpath('.//div[@class="inventory_left"]')
xbyHTML = inventory_left.get_attribute("outerHTML")
print('小保养')
print(xbyHTML)

# 2.遍历点击所有保养项目(可能会出现保养项目同时做提示，需关闭，否则无法正确点击)
search = driver.find_elements_by_tag_name('dd')
for i in search:
    i.click()
time.sleep(2)

# 检测保养关联提示，出现时关闭
tips = driver.find_element_by_xpath('.//div[@id="package_baoyang"]').find_elements_by_xpath('.//a[@class="btn"]')
if tips:
    for tip in tips:
        tip.click()          

# 再次检测除小保养外，所有未点击的保养项目，若存在则点击
not_checked = driver.find_elements_by_xpath('.//dd[not(contains(@class,"checked"))]')
for j in not_checked:
    if j.get_attribute('data-type') == 'xby':
        pass
    else:
        j.click()
time.sleep(3)
allHTML = inventory_left.get_attribute("outerHTML")
print('所有保养')
print(allHTML)
# Out:
# 小保养
# <div class="inventory_left">
#                 <div class="inventory">
#                     <div class="car-info" style="display: block;">
#                         <span class="tit">车型信息</span>
#
#                     <a id="chooseTid" class="txt-btn" data-key="款型">款型:2013款 3.0T 手自一体 45TFSI Quattro 四驱 越野版<i></i></a></div>
#                     <div class="title">
#                         <ul>
#                             <li style="width:130px;">保养项目</li>
#                             <li style="width:300px;">已选购产品</li>
#                             <li style="width:130px;">单价</li>
#                             <li style="width:150px;">数量</li>
#                         </ul>
#                     </div>
#
# ...

# %%
'''
PART3
BeautifulSoup解析左侧页面保养项目data_type,bytype,data_pid
'''
import json
from bs4 import BeautifulSoup

bsObj = BeautifulSoup(allHTML,'lxml')

# 所有保养项目列表
data_types = bsObj.find_all('div',{'class':'packageService open'})
for data_type in data_types:
    # data-type
    single_data_type = data_type.attrs['data-type']
    # print(single_data_type)
    # data-type下所有BaoYangType列表
    all_BaoYangType = data_type.find_all('tr')
    for BaoYangType in all_BaoYangType:
        # 每个BaoYangType下有两个td标签，第一个包含bytype信息，第二个包含pid信息
        td = BaoYangType.find_all('td')
        bytype = td[0].find('div',{'class':'BaoYangType'}).attrs['bytype']
        bytype_name = td[0].find('p').get_text().strip()
        data_pids = td[1].find_all('div',{'class':'data_pid'})
        # data_pids为空时，表明销售型无此保养项目，忽略即可
        if data_pids:
            for data_pid in data_pids:
                single_data_pid = data_pid.attrs['data_pid']
                print(single_data_type,bytype,bytype_name,single_data_pid)


# print(type(xbyHTML))
# print(allHTML)
# Out:
# bmk bmk 刹车系统养护 AP-FLD-FBW050K|
# ecc ecc 发动机舱清洗 AP-3M-FDJCQXYHTC|1
# lsm lsm 发动机养护 LF-3M-PN69121|1
# pyc pyc 喷油嘴清洗 LF-3M-PN69113|1
# twc twc 三元催化清洗 LF-3M-PN08869|1
# fic fic 进气系统清洗 LF-3M-PN69114|1
# wtc wtc 水箱清洗 LF-PRE-SXQJJ|1
# wtm wtm 冷却系统养护 LF-PRE-SXBHJ|1
# rx rx 燃油系统养护 LF-3M-PN11218|1
# ebc ebvc 蒸发箱可视化清洗 LF-3M-PN6933|1
# asc asc 空调管路杀菌 LF-3M-PN69132|1
# bsa lbsa 左后减振器 JZ-KYB-HTXL|288
# bsa rbsa 右后减振器 JZ-KYB-HTXL|288
# fsa lfsa 左前减振器 JZ-SACHS-ZFT|10
# fsa rfsa 右前减振器 JZ-SACHS-ZFT|10
# ffdyn ffdyn 雾灯 LF-OSRAM-CBP|4
# dyn fdyn 远光灯 LF-OSRAM-CBIXL|3
# dyn ndyn 近光灯 LF-OSRAM-CBIXL|3
# mto ato 变速箱油 AP-AX-AFWS|1
# mto atop 自动变速箱养护包 GS-MAHLE-TZ|15
# scp scpb 刹车片后 BR-FLD-SCPIAN|85
# scpan scpanb 刹车盘后 BD-FLD-SCPAN|119
# abp gbs 发电机皮带套装 AP-GATES-KTTB|3
# hhs hhs 火花塞 VA-CHAMPION-SBJHHS|16
# scy scy 刹车油 AP-BOSCH-ENV6|1
# fd gfd 更换防冻冷却液 AP-CHAMPION-AFC|7
# lm lm 空调制冷剂 LM-Honeywell-R134a|1
# lm ldy 冷冻油 LM-CHAMPION-TBD|1
# hys hys 非总成后雨刷 WP-LKK-HYSWG|21
# ys qys 前雨刷 WP-BO-3397007297-T|
# ...

# %%
'''
通过传参访问销售型所有保养具体项目及每项保养项目的描述、保养时间间隔
'''

import requests
from bs4 import BeautifulSoup
from selenium import webdriver

#url = 'https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle=%7B%22Brand%22%3A%22B+-+%E5%88%AB%E5%85%8B%22%2C%22VehicleId%22%3A%22VE-LSG-EXCELLEGX%22%2C%22PaiLiang%22%3A%221.3T%22%2C%22Nian%22%3A%222018%22%2C%22Tid%22%3A%22%22%2C%22Properties%22%3Anull%7D'
Brand = 'B - 宝马'
VehicleId = 'VE-LBV-118i'
PaiLiang = '1.5T'
Nian = '2017'
Tid = '109354'
url = 'https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle={"Brand":"%s","VehicleId":"%s","PaiLiang":"%s","Nian":"%s","Tid":"%s","Properties":"null"}' % (Brand,VehicleId,PaiLiang,Nian,Tid)
print(url)
#url = 'https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle={}'.format(vehicle_dict)
#print(url)
# url = "https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle={'Brand': 'B - 宝马', 'VehicleId': 'VE-LBV-118i', 'PaiLiang': '1.5T', 'Nian': '2017', 'Tid': '109354', 'Properties': 'null'}"
headers = {
    "authority":"by.tuhu.cn",
    "scheme":"https",
    "accept":"*/*",
    "accept-encoding":"gzip, deflate, br",
    "accept-language":"zh-CN,zh;q=0.9",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36",
}
# params = {"Brand":"B - 宝马","VehicleId":"VE-LBV-118i","PaiLiang":"1.5T","Nian":"2017","Tid":"109354","Properties":"null"}

response = requests.get(url,headers=headers)
response.close()
response_str = response.content.decode('utf-8')

# 处理NULL值,false,true
response_str = response_str.replace('null','""').replace('false','"false"').replace('true','"true"')
# 转为列表形式(列表元素为三大保养分类的字典形式)
response_list = eval(response_str)
print(response_list)
# Out:
# https://by.tuhu.cn/change/GetBaoYangPackageDescription.html?vehicle={"Brand":"B - 宝马","VehicleId":"VE-LBV-118i","PaiLiang":"1.5T","Nian":"2017","Tid":"109354","Properties":"null"}
# ...

# %%
'''
保养项目的描述、保养时间间隔 解析

'''
# 重置以data-type为键的字典，方便后续提取
data_type_dict = {}

for category_dict in response_list:
    # 提取保养类别
    CategoryType = category_dict['CategoryType']
    # 提取保养类别名称
    CategoryName = category_dict['CategoryName']
    SimpleCategoryName = category_dict['SimpleCategoryName']
    # 提取保养类别下需要做的具体保养项目信息（列表形式，元素为字典形式的各个具体保养项目）
    Items = category_dict['Items']
    for package in Items:
        # 提取保养项目 PackageType（相当于data-type）
        PackageType = package['PackageType']
        # 提取保养项目中文名
        ZhName = package['ZhName']
        # 提取保养简述
        BirefDescription = package['BirefDescription']
        # 提取保养建议
        SuggestTip = package['SuggestTip']
        # 提取详细说明
        DetailDescription = package['DetailDescription']
        # 是否紧急
        IsVeryUrgent = package['IsVeryUrgent']
        # 推荐文本
        RecommendText = package['RecommendText']
        
        data_type_dict[PackageType] = {
            'ZhName':ZhName,
            'CategoryType':CategoryType,
            'CategoryName':CategoryName,
            'SuggestTip':SuggestTip,
            'BirefDescription':BirefDescription,
            'IsVeryUrgent':IsVeryUrgent,
            'DetailDescription':DetailDescription,
            'RecommendText':RecommendText
        }
print(data_type_dict)
# Out:
# {'xby': {'ZhName': '小保养服务', 'CategoryType': 'Normal', 'CategoryName': '常规保养', 'SuggestTip': '5000km或6个月/次', 'BirefDescription': '更换机油和机油滤芯，保护发动机正常工作', 'IsVeryUrgent': 'false', 'DetailDescription': '', 'RecommendText': ''}, 'dby': {'ZhName': '大保养服务', 'CategoryType': 'Normal', 'CategoryName': '常规保养', 'SuggestTip': '10000km或12个月/次', 'BirefDescription': '更换机油和机滤、空气滤、燃油滤', 'IsVeryUrgent': 'false', 'DetailDescription': '', 'RecommendText': ''}, 'kv': {'ZhName': '空调滤清器', 'CategoryType': 'Normal', 'CategoryName': '常规保养', 'SuggestTip': '12个月/次', 'BirefDescription': '有效过滤烟臭、花粉、尘埃、有害气体和异味', 'IsVeryUrgent': 'false', 'DetailDescription': '', 'RecommendText': ''}, 'ys': {'ZhName': '前雨刷', 'CategoryType': 'Normal', 'CategoryName': '常规保养', 'SuggestTip': '6个月/次', 'BirefDescription': '保障驾驶员在雨雪天气视线清晰', 'IsVeryUrgent': 'false', 'DetailDescription': '', 'RecommendText': ''}, 'lm': {'ZhName': '空调制冷剂', 'CategoryType': 'Normal', 'CategoryName': '常规保养', 'SuggestTip': '制冷效果不佳时', 'BirefDescription': '冷媒，雪种，热量的搬
# ...

# %%
'''
通过具体销售型信息，及需要采集的保养项目信息
传参
获取各个销售型具体保养项目的所有保养件信息

'''

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
import time
import json

# 请求头设置
# referer 为上步获取bytype,data-pid时，转码后的url
headers = {
    #"authority":"by.tuhu.cn",
    #"method":"POST",
    #"path":"/change/ChangeProduct.html",
    "scheme":"https",
    "accept":"*/*",
    "accept-encoding":"gzip, deflate, br",
    "accept-language":"zh-CN,zh;q=0.9",
    "x-requested-with":"XMLHttpRequest",
    "content-type":"application/x-www-form-urlencoded; charset=UTF-8",
    "user-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36",
    "origin":"https://by.tuhu.cn",
    "referer":"https://by.tuhu.cn/baoyang/VE-LSG-EXCELLEGX/pl1.3T-n2018.html?tid=118058",
}

data = {
    # "vehicle":{"Brand":"B - 别克","FuelType":"","Nian":"2018","PaiLiang":"1.3T","Properties":[],"SalesName":"2019款 1.3T 手自一体 互联旗舰版（国V排放）","Tid":"118058","VehicleId":"VE-LSG-EXCELLEGX","CarID":"{bccc04c6-e594-424c-a90d-68e724e05ca4}","Vehicle":"阅朗-上汽通用别克","TotalMileage":0,"LastBaoYangKM":0,"CartypeDescription":" 别克 阅朗 1.3T 2018年产 2019款 1.3T 手自一体 互联旗舰版（国V排放）","CarNumber":"","LastBaoYangTime":"0001-01-01T00:00:00","IsDefaultCar":True,"LIYANGID":""},
    # "vehicle":'{"Brand":"B - 别克","FuelType":"","Nian":"2018","OnRoadTime":"null","PaiLiang":"1.3T","Properties":[],"SalesName":"2019款 1.3T 手自一体 互联旗舰版（国V排放）","Tid":"118058","VehicleId":"VE-LSG-EXCELLEGX","CarID":"{bccc04c6-e594-424c-a90d-68e724e05ca4}","BuyYear":"null","BuyMonth":"null","Vehicle":"阅朗-上汽通用别克","TotalMileage":0,"LastBaoYangKM":0,"CartypeDescription":" 别克 阅朗 1.3T 2018年产 2019款 1.3T 手自一体 互联旗舰版（国V排放）","CartypeOther":"null","CarNumber":"","Classno":"null","Engineno":"null","Carno_City":"null","Carno_Province":"null","LastBaoYangTime":"0001-01-01T00:00:00","IsDefaultCar":"true","LIYANGID":"","TireSizeForSingle":"null","Registrationtime":"null"}',
    # "vehicle":{"Brand":"B - 别克","Nian":"2018","PaiLiang":"1.3T","SalesName":"2019款 1.3T 手自一体 互联旗舰版（国V排放）","VehicleId":"VE-LSG-EXCELLEGX","Vehicle":"阅朗-上汽通用别克"},
    "vehicle":'{"Brand":"D - 大众","FuelType":"","Nian":"2016","OnRoadTime":"","PaiLiang":"1.4T-混合动力","Properties":[],"SalesName":"2015款 1.4T 双离合 GTE","Tid":"16615","VehicleId":"VE-GOLFJK","Vehicle":"Golf GTE-大众进口"}',
    "baoyangType":"jv",
    "pid":"FI-ML-OC1196|"
}

url = "https://by.tuhu.cn/change/ChangeProduct.html"

# response = requests.post(url=url,headers=headers,data=data,verify=False)
response = requests.post(url=url,headers=headers,data=data)

time.sleep(3)

# 关闭
response.close()

print(response.text)
# 查看请求头，传参body
# print(response.request.body)
# print(response.request.headers)
# Out:
# {"Brand":["马勒/MAHLE","博世/BOSCH","意奔玛","冠军/CHAMPION","美孚/Mobil"],"Data":{"1":[{"Pid":"FI-ML-OC1196|","DisplayName":"马勒/MAHLE 机油滤清器 OC1196","Brand":"马勒/MAHLE","BrandImage":"https://img4.tuhu.org/Images/Logos/1608/3BE2DCED0C5446B3.png@120w_40h_100Q.png","Image":"https://img3.tuhu.org/Images/Products/eb59/4ad3/d970567031bd3950baebf317_w800_h800.jpg@163w_163h_100Q.jpg","Price":25.0000,"Stockout":false,"Count":0,"Unit":"个","Tags":[{"Type":"Gift","Tag":"赠品","TagColor":"#df3348"}],"Gifts":[{"Tag":{"Type":"Gift","Tag":"赠","TagColor":"#df3348"},"Description":"购买任意马勒品牌产品安装完成后即可获得一次抽奖机会， (多次购买最多只能获得一次抽奖机会）；平台将于三个工作日内发送抽奖短信至已安装用户，用户可通过短信内链接参与抽奖；或者，订单安装后三个工作日内，用户可在途虎APP搜索“马勒抽奖”参与抽奖。","DisplayName":"购买任意马勒品牌产品安装完成后即可获得一次抽奖机会， (多次购买最多只能获得一次抽奖机会）；平台将于三个工作日内发送抽奖短信至已安装用户，用户可通过短信内链接参与抽奖；或者，订单安装后三个工作日内，用户可在途虎APP搜索“马勒抽奖”参与抽奖。","Pid":"FU-TUHU-BYLPDHQ|66"}],"IsOriginal":false},{"Pid":"FI-BOSCH-AF0267|","DisplayName":"博世/BOSCH 机油滤清器 0986AF0267","Brand":"博世/BOSCH","BrandImage":"https://img3.tuhu.org/Images/Lo
# ...

# %%
'''
最终保养件信息解析入库

'''
response_str = response.text
# 处理NULL值,false,true,并转为字典形式
response_str = response_str.replace('null','""').replace('false','"false"').replace('true','"true"')
response_dict = eval(response_str)
# print(type(response_dict))

# Data中包含所有页的保养产品信息,以页数为键，每页保养产品信息列表为值组成的字典
all_data = response_dict['Data']
maintenance_parts_list = []
# 判断是否存在保养件信息
if all_data:
    for page,p_info in all_data.items():
        # 每个产品信息为字典形式
        for p_dict in p_info:
            Pid = p_dict['Pid']
            DisplayName = p_dict['DisplayName']
            Brand = p_dict['Brand']
            
            BrandImage = p_dict['BrandImage']
            Image = p_dict['Image']
            # 处理图片链接，修正为原始尺寸图片链接
            BrandImage = BrandImage[:BrandImage.find('@')] if BrandImage.count('@')==1 else BrandImage
            Image = Image[:Image.find('@')] if Image.count('@')==1 else Image
            
            Price = p_dict['Price']
            Unit = p_dict['Unit']
            IsOriginal = p_dict['IsOriginal']
            
            maintenance_parts_list.append([Pid,DisplayName,Brand,BrandImage,Image,Price,Unit,IsOriginal])
else:
    print('无保养件信息（）')
print(maintenance_parts_list)
# Out:
# [['FI-ML-OC1196|', '马勒/MAHLE 机油滤清器 OC1196', '马勒/MAHLE', 'https://img4.tuhu.org/Images/Logos/1608/3BE2DCED0C5446B3.png', 'https://img3.tuhu.org/Images/Products/eb59/4ad3/d970567031bd3950baebf317_w800_h800.jpg', 25.0, '个', 'false'], ['FI-BOSCH-AF0267|', '博世/BOSCH 机油滤清器 0986AF0267', '博世/BOSCH', 'https://img3.tuhu.org/Images/Logos/1608/7889AD6F80CA2D49.png', 'https://img3.tuhu.org/Images/Products/1ce2/f6c9/594811b32723cde7b0a62c4e_w800_h800.png', 25.0, '个', 'false'], ['FI-YBM-512058|', '意奔玛 机油滤清器 512058', '意奔玛', 'https://img4.tuhu.org/Images/Logos/1608/386D7A284D4BF824.png', 'https://img3.tuhu.org/Images/Products/0820/4a7c/b0836688015a66adc268d7d0_w560_h560.jpg', 16.0, '只', 'false'], ['FI-CHAMPION-OIL|7', '【百年美国品牌】冠军/CHAMPION 机油滤清器 CM107-03', '冠军/CHAMPION', 'https://img3.tuhu.org/Images/Logos/1608/7EF635DCD24F301E.png', 'https://img4.tuhu.org/Images/Products/Fh_G2CrXMQcgUsxMy-vPc1x80Mec_w800_h800.jpeg', 19.0, '个', 'false'], ['FI-MO-OIL|4', '美孚/MOBIL 美孚1号 长效款机油滤清器 M1 Filter EP-004', '美孚/M
# ...

# %%
import pymysql

aaa = {1:2,
      'sss':'34'}
bbb = str(aaa)
print(aaa)
# Out:
# {1: 2, 'sss': '34'}
