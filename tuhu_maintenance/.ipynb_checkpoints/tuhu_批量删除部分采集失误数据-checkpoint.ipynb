# %%
# coding=utf-8
import pymysql

# 传入由元组组成的列表，按条件批量删除MySQL数据
def delete_date_from_MySQL(delete_lists):
    conn = pymysql.connect(host='127.0.0.1', user='root', passwd='123456', db='MySQL', charset='utf8')
    cur = conn.cursor()
    cur.execute('USE tuhu_maintenance')
    sql = '''
        DELETE FROM `sales_vehicle_bytype_and_products`
        WHERE tid = %s AND product_year = %s;
    '''
    rows = cur.executemany(sql, delete_lists)
    conn.commit()
    cur.close()
    conn.close()

# %%
delete_lists = [('14921', '2016'), ('1603', '2010'), ('1611', '2008'), ('1620', '2014'), ('14922', '2016'), ('1392', '2015'), ('1396', '2016'), ('1622', '2012'), ('1628', '2011'), ('1625', '2013'), ('1630', '2014'), ('103395', '2016'), ('103388', '2018'), ('118905', '2019'), ('774', '2008'), ('776', '2011'), ('832', '2008'), ('10667', '2015'), ('15396', '2016'), ('111838', '2018'), ('111844', '2018'), ('115421', '2012'), ('105886', '2015'), ('105889', '2015'), ('105864', '2017'), ('105865', '2017'), ('118346', '2019'), ('118347', '2019'), ('118348', '2019'), ('101131', '2017'), ('11899', '2012'), ('100038', '2014'), ('110043', '2018'), ('110019', '2017'), ('110023', '2017'), ('110026', '2017'), ('110030', '2018'), ('110031', '2018'), ('110032', '2018'), ('110031', '2019'), ('113460', '2018'), ('122349', '2018'), ('122350', '2018'), ('122351', '2018'), ('122349', '2019'), ('122350', '2019'), ('122351', '2019'), ('10010', '2007'), ('13255', '2015'), ('3603', '2008'), ('3639', '2012'), ('3640', '2013'), ('3642', '2013'), ('3639', '2014'), ('3641', '2014'), ('3641', '2015'), ('3642', '2015'), ('3593', '2006'), ('9114', '2013'), ('9125', '2014'), ('9130', '2015'), ('12504', '2016'), ('848', '2006'), ('850', '2006'), ('848', '2007'), ('850', '2007'), ('848', '2008'), ('850', '2008'), ('848', '2009'), ('850', '2009'), ('848', '2010'), ('850', '2010'), ('848', '2011'), ('850', '2011'), ('857', '2011'), ('858', '2011'), ('859', '2011'), ('860', '2011'), ('857', '2012'), ('859', '2012'), ('860', '2012'), ('857', '2013'), ('859', '2013'), ('860', '2013'), ('857', '2014'), ('859', '2014'), ('860', '2014'), ('857', '2015'), ('859', '2015'), ('860', '2015'), ('857', '2016'), ('859', '2016'), ('860', '2016'), ('857', '2017'), ('859', '2017'), ('860', '2017'), ('857', '2018'), ('859', '2018'), ('860', '2018'), ('857', '2019'), ('859', '2019'), ('860', '2019'), ('852', '2006'), ('852', '2007'), ('852', '2008'), ('852', '2009'), ('852', '2010'), ('852', '2011'), ('117225', '2018'), ('117260', '2019'), ('117261', '2019'), ('117228', '2019'), ('101960', '2001'), ('101960', '2002'), ('101960', '2003'), ('101960', '2004'), ('100365', '2000'), ('100365', '2001'), ('100366', '2003'), ('100368', '2003'), ('100366', '2004'), ('100368', '2004'), ('100366', '2005'), ('100368', '2005'), ('100366', '2006'), ('100368', '2006'), ('100366', '2007'), ('100368', '2007'), ('100366', '2008'), ('13044', '2015'), ('13045', '2016'), ('120588', '2014'), ('12507', '2015'), ('111123', '2019'), ('111124', '2019'), ('111125', '2019'), ('13098', '2019'), ('113932', '2018'), ('113932', '2019')]
test_lists = [('14921', '2016'), ('1603', '2010')]

# 删除 example_products_html
# delete_date_from_MySQL(delete_lists)

# 删除 products_html
# delete_date_from_MySQL(delete_lists)

# 删除 sales_vehicle_bytype_and_products
delete_date_from_MySQL(delete_lists)
