# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from lxml import etree

import re
import csv
import math
import time
import requests


# 请求头设置
session = requests.Session()

headers = {
    "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
    "Accept-Encoding":"gzip, deflate, sdch",
    "Accept-Language":"zh-CN,zh;q=0.8",
    "Cache-Control":"max-age=0",
    "Connection":"keep-alive",
    "Cookie":"uuid=776540427167433; UM_distinctid=16b0c96ecba606-039b8a5346352d-3764460c-1fa400-16b0c96ecbb378; ASP.NET_SessionId=2coepfaqerhc1damfl4odk45; uuid=776540427167433; CNZZDATA2115974=cnzz_eid%3D2124487544-1559281376-null%26ntime%3D1560916615; Hm_lvt_d08ac25fd4c45e85e8d9f1c32e97a0eb=1559284347,1560854045,1560907550; Hm_lpvt_d08ac25fd4c45e85e8d9f1c32e97a0eb=1560921756",
    "Host":"www.12365auto.com",
    "Referer":"http://www.12365auto.com/zlts/0-0-0-0-0-0_0-0-1.shtml",
    "Upgrade-Insecure-Requests":"1",
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/49.0.2623.112 Safari/537.36"
}


url = "http://www.12365auto.com/zlts/0-0-0-0-0-0_0-0-2.shtml"

html = session.get(url, headers=headers).content

bsObj = BeautifulSoup(html,'lxml')

print(bsObj)

# 获取标题列表
table_title = []

title_id_list = bsObj.find('table').find('tr').find_all('th')

for title in title_id_list:
    table_title.append(title.get_text())

data_list = bsObj.find('table').find_all('tr')

for data in data_list:
    data_text_list = data.find_all('td')
    #for data_text in data_text_list:
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta content="all" name="robots"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>汽车质量投诉 - 车质网</title>
# <meta content="汽车投诉,投诉,汽车质量投诉,汽车质量,汽车维权,汽车缺陷,汽车服务" name="keywords"/>
# <meta content="车质网投诉频道为消费者提供一个公平、公正、公开的投诉平台，收集、反馈、解决消费者爱车的故障与问题，让消费者能有一个把心里话释放的港湾。还可以查询车辆的相关投诉与共性问题，为消费者选车买车提供参考。" name="description"/>
# ...

# %%
from selenium import webdriver
import time
from bs4 import BeautifulSoup

# 需要在Selenium的WebDriver接入点指明PhantomJS可执行文件的路径
driver = webdriver.PhantomJS(executable_path="D:/Program Files/phantomjs-2.1.1-windows/bin/phantomjs")
driver.get("http://www.12365auto.com/zlts/0-0-0-0-0-0_0-0-8506.shtml")



# 如果time.sleep(1)则返回跳转前的页面信息
# time.sleep(1)
pageSource = driver.page_source

bsObj = BeautifulSoup(pageSource,'lxml')

driver.close()

# 获取标题列表
table_title = []

title_id_list = bsObj.find('table').find('tr').find_all('th')

for title in title_id_list:
    table_title.append(title.get_text())
#print(table_title)


# 获取投诉记录表单数据
data_list = bsObj.find('table').find_all('tr')
for data in data_list:
    data_text_list = data.find_all('td')
    '''
    for data_text in data_text_list:
        print(data_text)
    '''
    for i in range(len(data_text_list)):
        print(data_text_list[i].get_text())

        # 获取投诉车系网页信息中的各种ID
        if i == 2:
            bid = data_text_list[i]['bid']
            sid = data_text_list[i]['sid']
            mid = data_text_list[i]['mid']
            print(bid,sid,mid)

        # 获取问题简述的网页跳转链接
        if i == 4:
            tsjs_href = data_text_list[i].find('a')['href']
            print(tsjs_href)

        # 典型问题解析
        if i == 5:
            span_list = data_text_list[i].find_all('span')

            # 典型问题处理字符串
            wt_str = ''

            for span in span_list:
                print(span['class'])

                if len(span['class']) == 1 and span['class'][0] in ['bw','fwwt']:
                    wt_str = '%s:%s' % (wt_str,span.get_text())
                    print('%s:' % span.get_text())
                #elif len(span['class']) == 1 and span['class'][0] in ['wt','fw']:
                #    print('%s;' % span.get_text())
                else:
                    print('%s;'% span.get_text())
                    wt_str = '%s;%s' % (wt_str, span.get_text())
                print(wt_str,len(wt_str))
                print(wt_str[1:])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-c74f7c06c297> in <module>()
# ----> 1 from selenium import webdriver
#       2 import time
#       3 from bs4 import BeautifulSoup
#       4
#       5 # 需要在Selenium的WebDriver接入点指明PhantomJS可执行文件的路径
#
# ModuleNotFoundError: No module named 'selenium'

# %%
import pymysql
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8748c87b3097> in <module>()
# ----> 1 import pymysql
#
# ModuleNotFoundError: No module named 'pymysql'
