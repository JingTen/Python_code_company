# %%
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import random
from bs4 import BeautifulSoup
from urllib.request import urlopen



# 设置PhantomJS请求头

page = 1

dcap = dict(DesiredCapabilities.PHANTOMJS)

dcap["phantomjs.page.settings.userAgent"] = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36")

driver = webdriver.PhantomJS(desired_capabilities=dcap)

url = "https://xl.16888.com/s/57415/"

url = "https://auto.16888.com/"

driver.get(url)

# 随机睡眠 
time.sleep(random.random()+0.3)

pageSource = driver.page_source

bsObj = BeautifulSoup(pageSource,'lxml')

driver.close()

# ------------------------------获取车主之家所有车系ID------------------------------

cs = bsObj.find_all(lambda tag:tag.has_attr("href") and tag.has_attr("target") and tag.has_attr('title'))

print(len(cs))

series_id_list = []

for i in cs:

    if "https://www.16888.com/" in i['href']:
        
        series_id = i['href'][22:-1]
        
        series_id_list.append(series_id)
        
print(series_id_list)

# %%
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import random
from bs4 import BeautifulSoup
from urllib.request import urlopen
import re




# 设置PhantomJS请求头

page = 1

dcap = dict(DesiredCapabilities.PHANTOMJS)

dcap["phantomjs.page.settings.userAgent"] = (
    "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.6 Safari/537.36")

driver = webdriver.PhantomJS(desired_capabilities=dcap)

url = "https://xl.16888.com/s/57415/"

#url = "https://xl.16888.com/s/128207/"

driver.get(url)

# 随机睡眠 
time.sleep(random.random()+3)

pageSource = driver.page_source

bsObj = BeautifulSoup(pageSource,'lxml')

driver.close()

# print(bsObj)


# ------------------------------获取最大页数-------------------------------------
page = bsObj.find('div',{'class':'xl-data-pageing lbBox'})

if page == None:
    print('无销量记录')
else:
    # 总页数
    last_page = int(bsObj.find_all('a',{'class':'lineBlock num'})[-1].get_text())
    
    # 总数量计算总页数
    
    count_num = bsObj.find('span',{'class':'lineBlock va-m'}).get_text()
    
    count_num = int(re.findall(re.compile(r'\d{1,}'),count_num)[0])
    
    total_page = count_num // 50 + 1
    
    pages = max(last_page,total_page)
    
    print(pages)
    
    
# ------------------------------获取品牌；厂商；车系名称------------------------------------
info = bsObj.find_all('a',{'class':'select-text selected'})

info_list = []

for i in info:
    id = i['data-bid']
    info_list.append(id)
    info_list.append(i.find('span').get_text())
    
if "选择品牌" in info_list or "选择厂商" in info_list or "选择车型" in info_list:
    print("未成功获取")
    
print(info_list)
    
    
    
# ----------------------------获取表单数据-----------------------------------------
tr_list = bsObj.find('tbody').find_all('tr')[1:]

car_body = bsObj.find('tbody').find('tr').find_all('th')[-1].get_text()

car_body = car_body.replace('在','').replace('排名','')

# 初始化每页年月销量记录
y_m_xl_page_list = []

for i in tr_list:
    td_list = i.find_all('td')
    
    # 初始化每条年月销量记录
    y_m_xl_list = []
    for j in td_list:
        data = j.get_text()
        y_m_xl_list.append(data)
        
    y_m_xl_list.append(car_body)
        
    y_m_xl_page_list.append(y_m_xl_list)
    
print(y_m_xl_page_list)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\selenium\webdriver\phantomjs\webdriver.py:49: UserWarning: Selenium support for PhantomJS has been deprecated, please use headless versions of Chrome or Firefox instead
#   warnings.warn('Selenium support for PhantomJS has been deprecated, please use headless '
# 3
# ['57411', '大众', '57412', '上汽大众', '57415', '朗逸']
